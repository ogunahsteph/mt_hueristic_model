# %%
import os
import numpy as np
import pandas as pd

#import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline

# Set the display options to show all columns, rows and overrride scientific notation
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x : '%.2f' %x)

# %%
# data1 =pd.read_csv(file_path)
data2 =pd.read_csv('C:\\Users\\Stephen.Oguna\\Downloads\\Merchant Data API 20.09.2023 (1).csv')
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\4247299588.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 =pd.read_csv('C:\\Users\\Stephen.Oguna\\Downloads\\Merchant Data API 20.09.2023 (1).csv')

# %%
data2.head(2)
# Out:
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2  mom_registration_date                profile  \
# 0              NaN            20230121.00  MTNU MoMoPay Informal
# 1              NaN            20171017.00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0        20/02/2023 10:25                      20/09/2023 18:33
# 1        11/11/2019 15:24                      20/09/2023 14:17
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                                20/09/2023 22:07
# 1                                             NaN
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                        20/09/2023 18:56                         4.00
# 1                        15/09/2023 17:26                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00               5526768.00               2905418.00
# 1                     1.00                 16000.00                 12500.00
#
#    MOM_momo_PAYMENT_AMT_1M   DAY_momo_PAYMENT_AMT  \
# 0                   183,346              97000.00
# 1                     2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0           20/09/2023 18:33             96000.00
# 1           20/09/2023 14:17             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00

# %%
data2.head(1)
# Out:
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2  mom_registration_date                profile  \
# 0              NaN            20230121.00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0        20/02/2023 10:25                      20/09/2023 18:33
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                                20/09/2023 22:07
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                        20/09/2023 18:56                         4.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00               5526768.00               2905418.00
#
#    MOM_momo_PAYMENT_AMT_1M   DAY_momo_PAYMENT_AMT  \
# 0                   183,346              97000.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0           20/09/2023 18:33             96000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M
# 0                   111.00                    71.00                    26.00

# %%
data=data2.copy

# %%
# data2 = data2.isna().sum()
# data2

# %%
data1=data2
data1.head(2)
# Out:
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2  mom_registration_date                profile  \
# 0              NaN            20230121.00  MTNU MoMoPay Informal
# 1              NaN            20171017.00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0        20/02/2023 10:25                      20/09/2023 18:33
# 1        11/11/2019 15:24                      20/09/2023 14:17
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                                20/09/2023 22:07
# 1                                             NaN
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                        20/09/2023 18:56                         4.00
# 1                        15/09/2023 17:26                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00               5526768.00               2905418.00
# 1                     1.00                 16000.00                 12500.00
#
#    MOM_momo_PAYMENT_AMT_1M   DAY_momo_PAYMENT_AMT  \
# 0                   183,346              97000.00
# 1                     2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0           20/09/2023 18:33             96000.00
# 1           20/09/2023 14:17             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00

# %%
# data2 = data2.to_frame()
# data2.columns = [str(col).replace(" ", "") for col in data2.columns]

# %%
# data2.columns = [col.replace(" ", "") for col in data2.columns]

# %%
data1.columns = [col.replace(" ", "") for col in data1.columns]

# %%
name_to_find = 'NAME'

for col in data1.columns:
    if name_to_find.lower() in col.lower():
        print(f"The col containing '{name_to_find}' is: {col}")
    
else:
    print(f"No feature contains '{name_to_find}'.")
# Out:
# The col containing 'NAME' is: kyc_first_name_2
# The col containing 'NAME' is: kyc_last_name_2
# No feature contains 'NAME'.

# %%
## converting date columns to datetime

date_cols  = [x for x in data1.columns if ('date' or 'DATE') in x]

# dates to datetime
data1['MoMoPay_fst_actvty_date'] = pd.to_datetime(data1['MoMoPay_fst_actvty_date'], format = '%d/%m/%Y %H:%M')
data1['date_last_receipt_into_momopay_wallet'] = pd.to_datetime(data1['date_last_receipt_into_momopay_wallet'], format = '%d/%m/%Y %H:%M')
data1['date_last_transfer_from_momopay_to_mobile_money'] = pd.to_datetime(data1['date_last_transfer_from_momopay_to_mobile_money'], format = '%d/%m/%Y %H:%M')
data1['date_last_transfer_from_momopay_to_bank'] = pd.to_datetime(data1['date_last_transfer_from_momopay_to_bank'], format = '%d/%m/%Y %H:%M')
data1['MOM_momo_PAYMENT_LAST_DATE'] = pd.to_datetime(data1['MOM_momo_PAYMENT_LAST_DATE'],format = '%d/%m/%Y %H:%M')
data1['mom_registration_date'] = pd.to_datetime(data1['mom_registration_date'], format='%Y%m%d')

data1[date_cols].head(2)
# Out:
#   mom_registration_date MoMoPay_fst_actvty_date  \
# 0            2023-01-21     2023-02-20 10:25:00
# 1            2017-10-17     2019-11-11 15:24:00
#
#   date_last_receipt_into_momopay_wallet  \
# 0                   2023-09-20 18:33:00
# 1                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank
# 0                     2023-09-20 18:56:00
# 1                     2023-09-15 17:26:00

# %%
## drop all rows with null merchant_code



data1 = data1.loc[data1['kyc_merchant_code'].notnull()]


data1.head(2)
# Out:
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00               5526768.00               2905418.00
# 1                     1.00                 16000.00                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00

# %%
current_time = pd.to_datetime('2023-09-20')

print(current_time)
# Out:
# 2023-09-20 00:00:00

# %%
## calculating time periods
data1['age_on_network_months']= (round(
     ((current_time).year - data1['mom_registration_date'].dt.year) * 12 +
      ((current_time).month - data1['mom_registration_date'].dt.month),0)+1)
 

data1['months_since_first_activity']= round(
     ((current_time).year - data1['MoMoPay_fst_actvty_date'].dt.year) * 12 +
      ((current_time).month - data1['MoMoPay_fst_actvty_date'].dt.month),0)
data1['days_since_first_activity'] = round((current_time - data1['MoMoPay_fst_actvty_date'] ) / np.timedelta64(1, 'D') + 1)

data1['days_btwn_joining_and_first_activity_date'] = round((data1['MoMoPay_fst_actvty_date'] - data1['mom_registration_date'] ) / np.timedelta64(1, 'D'))


data1['days_since_last_pay_in'] = round((current_time - data1['date_last_receipt_into_momopay_wallet']) / np.timedelta64(1, 'D'))

data1['days_since_last_payout_to_mobile_money'] = round((current_time - data1['date_last_transfer_from_momopay_to_mobile_money']) / np.timedelta64(1, 'D'))

data1['days_since_last_payout_to_bank'] = round((current_time - data1['date_last_transfer_from_momopay_to_bank']) / np.timedelta64(1, 'D'))

data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1343129510.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['age_on_network_months']= (round(
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1343129510.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['months_since_first_activity']= round(
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1343129510.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['days_since_first_activity'] = round((current_time - data1['MoMoPay_fst_actvty_date'] ) / np.timedelta64(1, 'D') + 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1343129510.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['days_btwn_joining_and_first_activity_date'] = round((data1['MoMoPay_fst_actvty_date'] - data1['mom_registration_date'] ) / np.timedelta64(1, 'D'))
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1343129510.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['days_since_last_pay_in'] = round((current_time - data1['date_last_receipt_into_momopay_wallet']) / np.timedelta64(1, 'D'))
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1343129510.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['days_since_last_payout_to_mobile_money'] = round((current_time - data1['date_last_transfer_from_momopay_to_mobile_money']) / np.timedelta64(1, 'D'))
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1343129510.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['days_since_last_payout_to_bank'] = round((current_time - data1['date_last_transfer_from_momopay_to_bank']) / np.timedelta64(1, 'D'))
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00               5526768.00               2905418.00
# 1                     1.00                 16000.00                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                     213.00                                      30.00
# 1                    1409.00                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank
# 0                           -1.00
# 1                            4.00

# %%
def calculate_std(row):
    return np.std(row)

# %%
# data1['days_since_first_activity']

# %% [markdown]
# ### Trading consistency

# %%
# def calculate_trading_consistency(df):
#     days_since_first_activity = df['days_since_first_activity']
#     no_activity_last_30_days = df['MOMO_No_Activity_QTY_1M']
#     no_activity_last_90_days = df['MOMO_No_Activity_QTY_3M']
#     no_activity_last_180_days = df['MOMO_No_Activity_QTY_6M']
    
    
#     if days_since_first_activity <= 30:
#         no_of_extra_days = 30 - days_since_first_activity
#         days_with_no_activity = no_activity_last_30_days - no_of_extra_days
#         trading_consistency = round(1 - (days_with_no_activity / days_since_first_activity),2)
#         return trading_consistency
#     elif days_since_first_activity > 30 and days_since_first_activity <= 90 :
#         no_of_extra_days = 90 - days_since_first_activity
#         days_with_no_activity = no_activity_last_90_days - no_of_extra_days
#         trading_consistency = round(1 - (days_with_no_activity / days_since_first_activity),2)
#         return trading_consistency
#     elif days_since_first_activity > 90 and days_since_first_activity <= 180 :
#         no_of_extra_days = 180 - days_since_first_activity
#         days_with_no_activity = no_activity_last_180_days - no_of_extra_days
#         trading_consistency = round(1 - (days_with_no_activity / days_since_first_activity),2)
#         return trading_consistency
#     elif days_since_first_activity > 180:
#         trading_consistency = round(1 - (no_activity_last_180_days / 180),2)
#         return trading_consistency



def calculate_trading_consistency(df):
    days_since_first_activity = df['days_since_first_activity']
    no_activity_last_30_days = df['MOMO_No_Activity_QTY_1M']
    no_activity_last_90_days = df['MOMO_No_Activity_QTY_3M']
    no_activity_last_180_days = df['MOMO_No_Activity_QTY_6M']

    if days_since_first_activity <= 30:
        if days_since_first_activity == 0:
            return 0  
        no_of_extra_days = 30 - days_since_first_activity
        days_with_no_activity = no_activity_last_30_days - no_of_extra_days
        trading_consistency = round(1 - (days_with_no_activity / days_since_first_activity), 2)
        return trading_consistency
    elif 30 < days_since_first_activity <= 90:
        if days_since_first_activity == 0:
            return 0 
        no_of_extra_days = 90 - days_since_first_activity
        days_with_no_activity = no_activity_last_90_days - no_of_extra_days
        trading_consistency = round(1 - (days_with_no_activity / days_since_first_activity), 2)
        return trading_consistency
    elif 90 < days_since_first_activity <= 180:
        if days_since_first_activity == 0:
            return 0  
        no_of_extra_days = 180 - days_since_first_activity
        days_with_no_activity = no_activity_last_180_days - no_of_extra_days
        trading_consistency = round(1 - (days_with_no_activity / days_since_first_activity), 2)
        return trading_consistency
    elif days_since_first_activity > 180:
        if 180 == 0:
            return 0  # Avoid division by zero
        trading_consistency = round(1 - (no_activity_last_180_days / 180), 2)
        return trading_consistency

# %%
data1['trading_consistency'] = data1.apply(lambda x : calculate_trading_consistency(x), axis = 1)

data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3564451787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['trading_consistency'] = data1.apply(lambda x : calculate_trading_consistency(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00               5526768.00               2905418.00
# 1                     1.00                 16000.00                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                     213.00                                      30.00
# 1                    1409.00                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency
# 0                           -1.00                 0.38
# 1                            4.00                 0.16

# %% [markdown]
# ### Average daily transacted amount

# %%
data1['days_since_first_activity'] = data1['days_since_first_activity'].fillna(1).astype(int)
data1['MOM_momo_PAYMENT_AMT_6M'] = data1['MOM_momo_PAYMENT_AMT_6M'].fillna(1).astype(int)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1741614366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['days_since_first_activity'] = data1['days_since_first_activity'].fillna(1).astype(int)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1741614366.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['MOM_momo_PAYMENT_AMT_6M'] = data1['MOM_momo_PAYMENT_AMT_6M'].fillna(1).astype(int)

# %%
def calculate_average_daily_amount_last_6_months(df):

    days_since_first_activity = df['days_since_first_activity']
    total_value_last_6_months = df['MOM_momo_PAYMENT_AMT_6M']
    
    
    if days_since_first_activity > 90 and days_since_first_activity <= 180:
        average_transaction_size_last_6_months = total_value_last_6_months / days_since_first_activity
        return average_transaction_size_last_6_months
    elif days_since_first_activity > 180 :
        average_transaction_size_last_6_months = total_value_last_6_months / 180
        return average_transaction_size_last_6_months

# %%
column_data_type = data1['MOM_momo_PAYMENT_AMT_6M'].dtypes
column_data_type
# Out:
# dtype('int32')

# %%
def calculate_average_daily_amount_last_3_months(df):
   
    days_since_first_activity = df['days_since_first_activity']
    total_value_last_3_months = df['MOM_momo_PAYMENT_AMT_3M']
    
    if days_since_first_activity > 30 and days_since_first_activity <= 90 :
        average_transaction_size_last_3_months = total_value_last_3_months / days_since_first_activity
        return average_transaction_size_last_3_months
    elif days_since_first_activity > 90 :
        average_transaction_size_last_3_months = total_value_last_3_months / 90
        return average_transaction_size_last_3_months

# %%
def calculate_average_daily_amount_last_1_months(df):
    days_since_first_activity = df['days_since_first_activity']
    
    total_value_last_1_months = pd.to_numeric(df['MOM_momo_PAYMENT_AMT_1M'], errors='coerce')
    
    if days_since_first_activity <= 30 and days_since_first_activity > 0:
        average_transaction_size_last_1_months = total_value_last_1_months / days_since_first_activity
    elif days_since_first_activity > 30:
        average_transaction_size_last_1_months = total_value_last_1_months / 30
    else:
        average_transaction_size_last_1_months = 0  
    
    return average_transaction_size_last_1_months

# %%
data1['average_daily_transacted_amount_last_6_months'] = data1.apply(lambda x : calculate_average_daily_amount_last_6_months(x), axis = 1)

data1['average_daily_transacted_amount_last_3_months'] = data1.apply(lambda x : calculate_average_daily_amount_last_3_months(x), axis = 1)

data1['average_daily_transacted_amount_last_1_months'] = data1.apply(lambda x : calculate_average_daily_amount_last_1_months(x), axis = 1)

data1.head(1)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1804867921.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_transacted_amount_last_6_months'] = data1.apply(lambda x : calculate_average_daily_amount_last_6_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1804867921.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_transacted_amount_last_3_months'] = data1.apply(lambda x : calculate_average_daily_amount_last_3_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1804867921.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_transacted_amount_last_1_months'] = data1.apply(lambda x : calculate_average_daily_amount_last_1_months(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
#
#    average_daily_transacted_amount_last_1_months
# 0                                            NaN

# %% [markdown]
# ### Transacted Amount Ratios

# %%
data1['ratio_average_daily_transacted_amount_last_1/6_months'] = round(data1['average_daily_transacted_amount_last_1_months'] / data1['average_daily_transacted_amount_last_6_months'],2)

data1['ratio_average_daily_transacted_amount_last_1/3_months'] = round(data1['average_daily_transacted_amount_last_1_months'] / data1['average_daily_transacted_amount_last_3_months'],2)



data1['ratio_average_daily_transacted_amount_last_3/6_months'] = round(data1['average_daily_transacted_amount_last_3_months'] / data1['average_daily_transacted_amount_last_6_months'],2)

data1.head(1)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\463746894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_transacted_amount_last_1/6_months'] = round(data1['average_daily_transacted_amount_last_1_months'] / data1['average_daily_transacted_amount_last_6_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\463746894.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_transacted_amount_last_1/3_months'] = round(data1['average_daily_transacted_amount_last_1_months'] / data1['average_daily_transacted_amount_last_3_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\463746894.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_transacted_amount_last_3/6_months'] = round(data1['average_daily_transacted_amount_last_3_months'] / data1['average_daily_transacted_amount_last_6_months'],2)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months
# 0                                               1.05

# %% [markdown]
# ### Standard Deviations

# %%
data1['std_average_daily_transacted_amount_last_1/6_months'] = data1[['average_daily_transacted_amount_last_1_months','average_daily_transacted_amount_last_6_months']].apply(calculate_std, axis = 1)

data1['std_average_daily_transacted_amount_last_1/3_months'] = data1[['average_daily_transacted_amount_last_1_months','average_daily_transacted_amount_last_3_months']].apply(calculate_std, axis = 1)



data1['std_average_daily_transacted_amount_last_3/6_months'] = data1[['average_daily_transacted_amount_last_3_months','average_daily_transacted_amount_last_6_months']].apply(calculate_std, axis = 1)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\730956450.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_transacted_amount_last_1/6_months'] = data1[['average_daily_transacted_amount_last_1_months','average_daily_transacted_amount_last_6_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\730956450.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_transacted_amount_last_1/3_months'] = data1[['average_daily_transacted_amount_last_1_months','average_daily_transacted_amount_last_3_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\730956450.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_transacted_amount_last_3/6_months'] = data1[['average_daily_transacted_amount_last_3_months','average_daily_transacted_amount_last_6_months']].apply(calculate_std, axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months
# 0                                             789.08
# 1                                              25.00

# %% [markdown]
# ### Average transaction size

# %%
def calculate_average_transaction_size_last_6_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_value_last_6_months = df['MOM_momo_PAYMENT_AMT_6M']
    total_count_last_6_months = df['MOM_momo_PAYMENT_QTY_6M']
    
    if days_since_first_activity > 90: 
        if total_count_last_6_months == 0 :
            average_transaction_size_last_6_months = -4
            return average_transaction_size_last_6_months
        else:
            average_transaction_size_last_6_months = total_value_last_6_months / total_count_last_6_months
            return average_transaction_size_last_6_months

# %%
def calculate_average_transaction_size_last_3_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_value_last_3_months = df['MOM_momo_PAYMENT_AMT_3M']
    total_count_last_3_months = df['MOM_momo_PAYMENT_QTY_3M']
    
    if days_since_first_activity > 30:
        if total_count_last_3_months == 0 :
            average_transaction_size_last_3_months = -4
            return average_transaction_size_last_3_months
        else:
            average_transaction_size_last_3_months = total_value_last_3_months / total_count_last_3_months
            return average_transaction_size_last_3_months

# %%
def calculate_average_transaction_size_last_1_months(df):
    total_value_last_1_months = pd.to_numeric(df['MOM_momo_PAYMENT_AMT_1M'], errors='coerce')
    total_count_last_1_months = pd.to_numeric(df['MOM_momo_PAYMENT_QTY_1M'], errors='coerce')
    days_since_first_activity = df['days_since_first_activity']
#     total_value_last_1_months = df['MOM_momo_PAYMENT_AMT_1M']
#     total_count_last_1_months = df['MOM_momo_PAYMENT_QTY_1M']
    
    if total_count_last_1_months == 0:
        average_transaction_size_last_1_months = -4
        return average_transaction_size_last_1_months
    else:
        average_transaction_size_last_1_months = total_value_last_1_months / total_count_last_1_months
        return average_transaction_size_last_1_months

# %%
data1['average_transaction_size_last_6_months'] = data1.apply(lambda x : calculate_average_transaction_size_last_6_months(x), axis = 1)

data1['average_transaction_size_last_3_months'] = data1.apply(lambda x : calculate_average_transaction_size_last_3_months(x), axis = 1)

data1['average_transaction_size_last_1_months'] = data1.apply(lambda x : calculate_average_transaction_size_last_1_months(x), axis = 1)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3670973612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_transaction_size_last_6_months'] = data1.apply(lambda x : calculate_average_transaction_size_last_6_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3670973612.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_transaction_size_last_3_months'] = data1.apply(lambda x : calculate_average_transaction_size_last_3_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3670973612.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_transaction_size_last_1_months'] = data1.apply(lambda x : calculate_average_transaction_size_last_1_months(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months
# 0                                     NaN
# 1                                     NaN

# %% [markdown]
# ### Ration of average Transaction Sizes

# %%
data1['ratio_average_trxn_size_last_1/6_months'] = round(data1['average_transaction_size_last_1_months'] / data1['average_transaction_size_last_6_months'],2)

data1['ratio_average_trxn_size_last_1/3_months'] = round(data1['average_transaction_size_last_1_months'] / data1['average_transaction_size_last_3_months'],2)



data1['ratio_average_trxn_size_last_3/6_months'] = round(data1['average_transaction_size_last_3_months'] / data1['average_transaction_size_last_6_months'],2)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\950183726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_trxn_size_last_1/6_months'] = round(data1['average_transaction_size_last_1_months'] / data1['average_transaction_size_last_6_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\950183726.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_trxn_size_last_1/3_months'] = round(data1['average_transaction_size_last_1_months'] / data1['average_transaction_size_last_3_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\950183726.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_trxn_size_last_3/6_months'] = round(data1['average_transaction_size_last_3_months'] / data1['average_transaction_size_last_6_months'],2)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months
# 0                                     2.20
# 1                                     1.00

# %% [markdown]
# ### stds of average txn sizes

# %%
data1['std_average_trxn_size_last_1/6_months'] = data1[['average_transaction_size_last_1_months','average_transaction_size_last_6_months']].apply(calculate_std, axis = 1)

data1['std_average_trxn_size_last_1/3_months'] = data1[['average_transaction_size_last_1_months','average_transaction_size_last_3_months']].apply(calculate_std, axis = 1)



data1['std_average_trxn_size_last_3/6_months'] = data1[['average_transaction_size_last_3_months','average_transaction_size_last_6_months']].apply(calculate_std, axis = 1)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2240381901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_trxn_size_last_1/6_months'] = data1[['average_transaction_size_last_1_months','average_transaction_size_last_6_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2240381901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_trxn_size_last_1/3_months'] = data1[['average_transaction_size_last_1_months','average_transaction_size_last_3_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2240381901.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_trxn_size_last_3/6_months'] = data1[['average_transaction_size_last_3_months','average_transaction_size_last_6_months']].apply(calculate_std, axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months
# 0                               12189.87
# 1                                   0.00

# %% [markdown]
# ### Count of transactions

# %%
def calculate_count_of_transactions_last_6_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_count_last_6_months = df['MOM_momo_PAYMENT_QTY_6M']
    
    if days_since_first_activity > 90 :
        return total_count_last_6_months

# %%
# def calculate_average_daily_transactions_last_6_months(df):
#     days_since_first_activity = df['days_since_first_activity']
#     count_of_transactions_last_6_months = df['count_of_transactions_last_6_months']
    
    
#     if days_since_first_activity <= 180:
#         average_daily_transactions_last_6_months = np.ceil(count_of_transactions_last_6_months / days_since_first_activity)
#         return average_daily_transactions_last_6_months
#     elif days_since_first_activity > 180:
#         average_daily_transactions_last_6_months = np.ceil(count_of_transactions_last_6_months / 180)
#         return average_daily_transactions_last_6_months
#     else: 
#         return -4




def calculate_average_daily_transactions_last_6_months(df):
    days_since_first_activity = df['days_since_first_activity']
    count_of_transactions_last_6_months = df['count_of_transactions_last_6_months']

    if days_since_first_activity <= 0:
        return -4  # Return a default value for zero or negative days_since_first_activity

    if days_since_first_activity <= 180:
        average_daily_transactions_last_6_months = np.ceil(count_of_transactions_last_6_months / days_since_first_activity)
    else:
        average_daily_transactions_last_6_months = np.ceil(count_of_transactions_last_6_months / 180)

    return average_daily_transactions_last_6_months

# %%
def calculate_count_of_transactions_last_3_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_count_last_3_months = df['MOM_momo_PAYMENT_QTY_3M']
    
    if days_since_first_activity > 30 :
        return total_count_last_3_months

# %%
# def calculate_average_daily_transactions_last_3_months(df):
#     days_since_first_activity = df['days_since_first_activity']
#     count_of_transactions_last_3_months = df['count_of_transactions_last_3_months']
    
    
#     if days_since_first_activity <= 90:
#         average_daily_transactions_last_3_months = np.ceil(count_of_transactions_last_3_months / days_since_first_activity)
#         return average_daily_transactions_last_3_months
#     elif days_since_first_activity > 90:
#         average_daily_transactions_last_3_months = np.ceil(count_of_transactions_last_3_months / 90)
#         return average_daily_transactions_last_3_months
#     else:
#         return -4



def calculate_average_daily_transactions_last_3_months(df):
    days_since_first_activity = df['days_since_first_activity']
    count_of_transactions_last_3_months = df['count_of_transactions_last_3_months']

    if days_since_first_activity <= 0:
        return -4  # Return a default value for zero or negative days_since_first_activity

    if days_since_first_activity <= 90:
        average_daily_transactions_last_3_months = np.ceil(count_of_transactions_last_3_months / days_since_first_activity)
    else:
        average_daily_transactions_last_3_months = np.ceil(count_of_transactions_last_3_months / 90)

    return average_daily_transactions_last_3_months

# %%
def calculate_count_of_transactions_last_1_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_count_last_1_months = df['MOM_momo_PAYMENT_QTY_1M']
    
    return total_count_last_1_months

# %%
# def calculate_average_daily_transactions_last_1_months(df):
#     days_since_first_activity = df['days_since_first_activity']
#     count_of_transactions_last_1_months = df['count_of_transactions_last_1_months']
    
    
#     if days_since_first_activity <= 30:
#         average_daily_transactions_last_1_months = np.ceil(count_of_transactions_last_1_months / days_since_first_activity)
#         return average_daily_transactions_last_1_months
#     elif days_since_first_activity > 30:
#         average_daily_transactions_last_1_months = np.ceil(count_of_transactions_last_1_months / 30)
#         return average_daily_transactions_last_1_months
#     else:
#         return -4


def calculate_average_daily_transactions_last_1_months(df):
    days_since_first_activity = df['days_since_first_activity']
    count_of_transactions_last_1_months = df['count_of_transactions_last_1_months']

    if days_since_first_activity <= 0:
        return -4  # Return a default value for zero or negative days_since_first_activity

    if days_since_first_activity <= 30:
        average_daily_transactions_last_1_months = np.ceil(count_of_transactions_last_1_months / days_since_first_activity)
    else:
        average_daily_transactions_last_1_months = np.ceil(count_of_transactions_last_1_months / 30)

    return average_daily_transactions_last_1_months

# %%
data1['count_of_transactions_last_6_months'] = data1.apply(lambda x : calculate_count_of_transactions_last_6_months(x), axis = 1)

data1['count_of_transactions_last_3_months'] = data1.apply(lambda x : calculate_count_of_transactions_last_3_months(x), axis = 1)

data1['count_of_transactions_last_1_months'] = data1.apply(lambda x : calculate_count_of_transactions_last_1_months(x), axis = 1)

data1.head(3)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3630486838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_transactions_last_6_months'] = data1.apply(lambda x : calculate_count_of_transactions_last_6_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3630486838.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_transactions_last_3_months'] = data1.apply(lambda x : calculate_count_of_transactions_last_3_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3630486838.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_transactions_last_1_months'] = data1.apply(lambda x : calculate_count_of_transactions_last_1_months(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
# 2    169050@momopay  720E74A187312803EB76E049F9275199          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
# 2        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
# 2              NaN            2023-03-22  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
# 2     2023-03-23 11:56:00                   2023-09-18 15:47:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
# 2                             2023-09-20 08:11:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
# 2                     2023-09-12 19:09:00                         8.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
# 2                   435.00                    21.00                    11.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
# 2                     0.00                 21762900               1600400.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
# 2               1,017,900                   NaN
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
# 2                         371.00                          15.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
# 2                          10.00                        0.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
# 2                    500000.00                    463000.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
# 2                    463000.00                       NaN
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
# 2        2023-09-18 15:47:00            720000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
# 2                        23.00                         8.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
# 2                         1.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
# 2                       2.00                       2.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
# 2                       2.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
# 2                  10292208.00                    601000.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
# 2                     50000.00                  50000.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
# 2                  720000.00                  720000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
# 2                  720000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
# 2                         8.00                         5.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
# 2                         2.00                      0.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
# 2                    428800.00                    315000.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
# 2                     30000.00                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
# 2                   127.00                    74.00                    23.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
# 2                   7.00                         6.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
# 2                        182                                       1.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
# 2                    1.00                                   -0.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
# 2                            7.00                 0.29
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
# 2                                      120905.00
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
# 2                                       17782.22
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
# 2                                               0.15
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
# 2                                           51561.39
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
# 2                                50029.66
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
# 2                                76209.52
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
# 2                                     1.52
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
# 2                               13089.93                               435.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
# 2                                21.00                                11.00

# %%
data1['count_of_transactions_last_6_months'].fillna(-4, inplace = True)

data1['count_of_transactions_last_3_months'].fillna(-4, inplace = True)

data1['count_of_transactions_last_1_months'].fillna(-4, inplace = True)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3531951037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_transactions_last_6_months'].fillna(-4, inplace = True)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3531951037.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_transactions_last_3_months'].fillna(-4, inplace = True)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3531951037.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_transactions_last_1_months'].fillna(-4, inplace = True)

# %%
data1['average_daily_transactions_last_6_months'] = data1.apply(lambda x : calculate_average_daily_transactions_last_6_months(x), axis = 1)

data1['average_daily_transactions_last_3_months'] = data1.apply(lambda x : calculate_average_daily_transactions_last_3_months(x), axis = 1)

data1['average_daily_transactions_last_1_months'] = data1.apply(lambda x : calculate_average_daily_transactions_last_1_months(x), axis = 1)

data1.head(3)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\4147146255.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_transactions_last_6_months'] = data1.apply(lambda x : calculate_average_daily_transactions_last_6_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\4147146255.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_transactions_last_3_months'] = data1.apply(lambda x : calculate_average_daily_transactions_last_3_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\4147146255.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_transactions_last_1_months'] = data1.apply(lambda x : calculate_average_daily_transactions_last_1_months(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
# 2    169050@momopay  720E74A187312803EB76E049F9275199          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
# 2        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
# 2              NaN            2023-03-22  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
# 2     2023-03-23 11:56:00                   2023-09-18 15:47:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
# 2                             2023-09-20 08:11:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
# 2                     2023-09-12 19:09:00                         8.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
# 2                   435.00                    21.00                    11.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
# 2                     0.00                 21762900               1600400.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
# 2               1,017,900                   NaN
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
# 2                         371.00                          15.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
# 2                          10.00                        0.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
# 2                    500000.00                    463000.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
# 2                    463000.00                       NaN
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
# 2        2023-09-18 15:47:00            720000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
# 2                        23.00                         8.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
# 2                         1.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
# 2                       2.00                       2.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
# 2                       2.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
# 2                  10292208.00                    601000.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
# 2                     50000.00                  50000.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
# 2                  720000.00                  720000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
# 2                  720000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
# 2                         8.00                         5.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
# 2                         2.00                      0.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
# 2                    428800.00                    315000.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
# 2                     30000.00                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
# 2                   127.00                    74.00                    23.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
# 2                   7.00                         6.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
# 2                        182                                       1.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
# 2                    1.00                                   -0.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
# 2                            7.00                 0.29
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
# 2                                      120905.00
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
# 2                                       17782.22
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
# 2                                               0.15
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
# 2                                           51561.39
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
# 2                                50029.66
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
# 2                                76209.52
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
# 2                                     1.52
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
# 2                               13089.93                               435.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
# 2                                21.00                                11.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
# 2                                      3.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    average_daily_transactions_last_1_months
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00

# %% [markdown]
# ### Transactions Ratios

# %%
data1['ratio_average_daily_transactions_last_1/6_months'] = round(data1['average_daily_transactions_last_1_months'] / data1['average_daily_transactions_last_6_months'],2)

data1['ratio_average_daily_transactions_last_1/3_months'] = round(data1['average_daily_transactions_last_1_months'] /data1['average_daily_transactions_last_3_months'],2)



data1['ratio_average_daily_transactions_last_3/6_months'] = round(data1['average_daily_transactions_last_3_months'] / data1['average_daily_transactions_last_6_months'],2)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3568100995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_transactions_last_1/6_months'] = round(data1['average_daily_transactions_last_1_months'] / data1['average_daily_transactions_last_6_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3568100995.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_transactions_last_1/3_months'] = round(data1['average_daily_transactions_last_1_months'] /data1['average_daily_transactions_last_3_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3568100995.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_transactions_last_3/6_months'] = round(data1['average_daily_transactions_last_3_months'] / data1['average_daily_transactions_last_6_months'],2)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months
# 0                                              0.50
# 1                                              1.00

# %% [markdown]
# ### Transaction Stds

# %%
data1['std_average_daily_transactions_last_1/6_months'] = data1[['average_daily_transactions_last_1_months','average_daily_transactions_last_3_months']].apply(calculate_std, axis = 1)

data1['std_average_daily_transactions_last_1/3_months'] = data1[['average_daily_transactions_last_1_months','average_daily_transactions_last_3_months']].apply(calculate_std, axis = 1)



data1['std_average_daily_transactions_last_3/6_months'] = data1[['average_daily_transactions_last_3_months','average_daily_transactions_last_6_months']].apply(calculate_std, axis = 1)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3089928022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_transactions_last_1/6_months'] = data1[['average_daily_transactions_last_1_months','average_daily_transactions_last_3_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3089928022.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_transactions_last_1/3_months'] = data1[['average_daily_transactions_last_1_months','average_daily_transactions_last_3_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3089928022.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_transactions_last_3/6_months'] = data1[['average_daily_transactions_last_3_months','average_daily_transactions_last_6_months']].apply(calculate_std, axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_3/6_months
# 0                                            0.50
# 1                                            0.00

# %% [markdown]
# ### Number of clients served

# %%
def calculate_count_of_clients_last_6_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_clients_last_6_months = df['MOM_momo_PAYMENT_ACCEPTORS_6M']
    
    if days_since_first_activity > 90 :
        return total_clients_last_6_months

# %%
# def calculate_average_daily_clients_last_6_months(df):
#     days_since_first_activity = df['days_since_first_activity']
#     count_of_clients_last_6_months = df['count_of_clients_last_6_months']
    
    
#     if days_since_first_activity <= 180:
#         average_daily_clients_last_6_months = np.ceil(count_of_clients_last_6_months / days_since_first_activity)
#         return average_daily_clients_last_6_months
#     elif days_since_first_activity > 180:
#         average_daily_clients_last_6_months = np.ceil(count_of_clients_last_6_months / 180)
#         return average_daily_clients_last_6_months
#     else: 
#         return -4


def calculate_average_daily_clients_last_6_months(df):
    days_since_first_activity = df['days_since_first_activity']
    count_of_clients_last_6_months = df['count_of_clients_last_6_months']

    if days_since_first_activity <= 0:
        return -4  # Return a default value for zero or negative days_since_first_activity

    if days_since_first_activity <= 180:
        average_daily_clients_last_6_months = np.ceil(count_of_clients_last_6_months / days_since_first_activity)
    else:
        average_daily_clients_last_6_months = np.ceil(count_of_clients_last_6_months / 180)

    return average_daily_clients_last_6_months

# %%
def calculate_count_of_clients_last_3_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_clients_last_3_months = df['MOM_momo_PAYMENT_ACCEPTORS_3M']
    
    if days_since_first_activity > 30 :
        return total_clients_last_3_months

# %%
# def calculate_average_daily_clients_last_3_months(df):
#     days_since_first_activity = df['days_since_first_activity']
#     count_of_clients_last_3_months = df['count_of_clients_last_3_months']
    
    
#     if days_since_first_activity <= 90:
#         average_daily_clients_last_3_months = np.ceil(count_of_clients_last_3_months / days_since_first_activity)
#         return average_daily_clients_last_3_months
#     elif days_since_first_activity > 90:
#         average_daily_clients_last_3_months = np.ceil(count_of_clients_last_3_months / 90)
#         return average_daily_clients_last_3_months
#     else: 
#         return -4
    
    
def calculate_average_daily_clients_last_3_months(df):
    days_since_first_activity = df['days_since_first_activity']
    count_of_clients_last_3_months = df['count_of_clients_last_6_months']

    if days_since_first_activity <= 0:
        return -4  # Return a default value for zero or negative days_since_first_activity

    if days_since_first_activity <= 90:
        average_daily_clients_last_3_months = np.ceil(count_of_clients_last_3_months / days_since_first_activity)
    else:
        average_daily_clients_last_3_months = np.ceil(count_of_clients_last_3_months / 90)

    return average_daily_clients_last_3_months

# %%
def calculate_count_of_clients_last_1_months(df):
    days_since_first_activity = df['days_since_first_activity']
    total_clients_1_months = df['MOM_momo_PAYMENT_ACCEPTORS_1M']
    
    return total_clients_1_months

# %%
# def calculate_average_daily_clients_last_1_months(df):
#     days_since_first_activity = df['days_since_first_activity']
#     count_of_clients_last_1_months = df['count_of_clients_last_1_months']
    
    
#     if pd.notnull(count_of_clients_last_1_months):
#         average_daily_clients_last_1_months = np.ceil(count_of_clients_last_1_months / days_since_first_activity)
#         return average_daily_clients_last_1_months
#     else:
#         return -4




def calculate_average_daily_clients_last_1_months(df):
    days_since_first_activity = df['days_since_first_activity']
    count_of_clients_last_1_months = df['count_of_clients_last_1_months']
    
    if pd.notnull(count_of_clients_last_1_months) and days_since_first_activity > 0:
        average_daily_clients_last_1_months = np.ceil(count_of_clients_last_1_months / days_since_first_activity)
        return average_daily_clients_last_1_months
    else:
        return -4

# %%
data1['count_of_clients_last_6_months'] = data1.apply(lambda x : calculate_count_of_clients_last_6_months(x), axis = 1)

data1['count_of_clients_last_3_months'] = data1.apply(lambda x : calculate_count_of_clients_last_3_months(x), axis = 1)

data1['count_of_clients_last_1_months'] = data1.apply(lambda x : calculate_count_of_clients_last_1_months(x), axis = 1)


data1.head(3)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1748571807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_clients_last_6_months'] = data1.apply(lambda x : calculate_count_of_clients_last_6_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1748571807.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_clients_last_3_months'] = data1.apply(lambda x : calculate_count_of_clients_last_3_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1748571807.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['count_of_clients_last_1_months'] = data1.apply(lambda x : calculate_count_of_clients_last_1_months(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
# 2    169050@momopay  720E74A187312803EB76E049F9275199          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
# 2        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
# 2              NaN            2023-03-22  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
# 2     2023-03-23 11:56:00                   2023-09-18 15:47:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
# 2                             2023-09-20 08:11:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
# 2                     2023-09-12 19:09:00                         8.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
# 2                   435.00                    21.00                    11.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
# 2                     0.00                 21762900               1600400.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
# 2               1,017,900                   NaN
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
# 2                         371.00                          15.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
# 2                          10.00                        0.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
# 2                    500000.00                    463000.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
# 2                    463000.00                       NaN
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
# 2        2023-09-18 15:47:00            720000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
# 2                        23.00                         8.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
# 2                         1.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
# 2                       2.00                       2.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
# 2                       2.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
# 2                  10292208.00                    601000.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
# 2                     50000.00                  50000.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
# 2                  720000.00                  720000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
# 2                  720000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
# 2                         8.00                         5.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
# 2                         2.00                      0.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
# 2                    428800.00                    315000.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
# 2                     30000.00                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
# 2                   127.00                    74.00                    23.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
# 2                   7.00                         6.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
# 2                        182                                       1.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
# 2                    1.00                                   -0.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
# 2                            7.00                 0.29
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
# 2                                      120905.00
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
# 2                                       17782.22
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
# 2                                               0.15
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
# 2                                           51561.39
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
# 2                                50029.66
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
# 2                                76209.52
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
# 2                                     1.52
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
# 2                               13089.93                               435.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
# 2                                21.00                                11.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
# 2                                      3.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
# 2                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
# 2                                            1.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
# 2                          371.00                           15.00
#
#    count_of_clients_last_1_months
# 0                            5.00
# 1                            4.00
# 2                           10.00

# %% [markdown]
# ### Average Clients Served

# %%
data1['average_daily_clients_last_6_months'] = data1.apply(lambda x : calculate_average_daily_clients_last_6_months(x), axis = 1)

data1['average_daily_clients_last_3_months'] = data1.apply(lambda x : calculate_average_daily_clients_last_3_months(x), axis = 1)

data1['average_daily_clients_last_1_months'] = data1.apply(lambda x : calculate_average_daily_clients_last_1_months(x), axis = 1)

data1.head(3)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2821994672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_clients_last_6_months'] = data1.apply(lambda x : calculate_average_daily_clients_last_6_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2821994672.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_clients_last_3_months'] = data1.apply(lambda x : calculate_average_daily_clients_last_3_months(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2821994672.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['average_daily_clients_last_1_months'] = data1.apply(lambda x : calculate_average_daily_clients_last_1_months(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
# 2    169050@momopay  720E74A187312803EB76E049F9275199          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
# 2        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
# 2              NaN            2023-03-22  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
# 2     2023-03-23 11:56:00                   2023-09-18 15:47:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
# 2                             2023-09-20 08:11:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
# 2                     2023-09-12 19:09:00                         8.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
# 2                   435.00                    21.00                    11.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
# 2                     0.00                 21762900               1600400.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
# 2               1,017,900                   NaN
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
# 2                         371.00                          15.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
# 2                          10.00                        0.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
# 2                    500000.00                    463000.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
# 2                    463000.00                       NaN
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
# 2        2023-09-18 15:47:00            720000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
# 2                        23.00                         8.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
# 2                         1.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
# 2                       2.00                       2.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
# 2                       2.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
# 2                  10292208.00                    601000.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
# 2                     50000.00                  50000.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
# 2                  720000.00                  720000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
# 2                  720000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
# 2                         8.00                         5.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
# 2                         2.00                      0.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
# 2                    428800.00                    315000.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
# 2                     30000.00                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
# 2                   127.00                    74.00                    23.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
# 2                   7.00                         6.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
# 2                        182                                       1.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
# 2                    1.00                                   -0.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
# 2                            7.00                 0.29
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
# 2                                      120905.00
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
# 2                                       17782.22
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
# 2                                               0.15
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
# 2                                           51561.39
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
# 2                                50029.66
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
# 2                                76209.52
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
# 2                                     1.52
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
# 2                               13089.93                               435.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
# 2                                21.00                                11.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
# 2                                      3.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
# 2                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
# 2                                            1.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
# 2                          371.00                           15.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
# 2                           10.00                                 3.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
# 2                                 5.00                                 1.00

# %% [markdown]
# ### Ratios Of Clients Served

# %%
data1['ratio_average_daily_clients_last_1/6_months'] = round(data1['average_daily_clients_last_1_months'] / data1['average_daily_clients_last_6_months'],2)

data1['ratio_average_daily_clients_last_1/3_months'] = round(data1['average_daily_clients_last_1_months'] / data1['average_daily_clients_last_3_months'],2)



data1['ratio_average_daily_clients_last_3/6_months'] = round(data1['average_daily_clients_last_3_months'] / data1['average_daily_clients_last_6_months'],2)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\492712480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_clients_last_1/6_months'] = round(data1['average_daily_clients_last_1_months'] / data1['average_daily_clients_last_6_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\492712480.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_clients_last_1/3_months'] = round(data1['average_daily_clients_last_1_months'] / data1['average_daily_clients_last_3_months'],2)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\492712480.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['ratio_average_daily_clients_last_3/6_months'] = round(data1['average_daily_clients_last_3_months'] / data1['average_daily_clients_last_6_months'],2)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
#
#    ratio_average_daily_clients_last_3/6_months
# 0                                         1.50
# 1                                         1.00

# %% [markdown]
# ### Stds Of Clients Served

# %%
data1['std_average_daily_clients_last_1/6_months'] = data1[['average_daily_clients_last_1_months','average_daily_clients_last_6_months']].apply(calculate_std, axis = 1)

data1['std_average_daily_clients_last_1/3_months'] = data1[['average_daily_clients_last_1_months','average_daily_clients_last_3_months']].apply(calculate_std, axis = 1)



data1['std_average_daily_clients_last_3/6_months'] = data1[['average_daily_clients_last_3_months','average_daily_clients_last_6_months']].apply(calculate_std, axis = 1)


data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1843553381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_clients_last_1/6_months'] = data1[['average_daily_clients_last_1_months','average_daily_clients_last_6_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1843553381.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_clients_last_1/3_months'] = data1[['average_daily_clients_last_1_months','average_daily_clients_last_3_months']].apply(calculate_std, axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1843553381.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['std_average_daily_clients_last_3/6_months'] = data1[['average_daily_clients_last_3_months','average_daily_clients_last_6_months']].apply(calculate_std, axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN                NaN        NaN               NaN
# 1        NRIN                NaN        NaN               NaN
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0              NaN            2023-01-21  MTNU MoMoPay Informal
# 1              NaN            2017-10-17  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                             NaT
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                          NaN                          NaN
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                          NaN                       NaN
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                     NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                          NaN                       NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                          NaN                          NaN
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                          NaN                       NaN
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                     NaN
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                            NaN
# 1                                            NaN
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                                NaN
# 1                                                NaN
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                     NaN
# 1                                     NaN
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                      NaN
# 1                                      NaN
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
#
#    ratio_average_daily_clients_last_3/6_months  \
# 0                                         1.50
# 1                                         1.00
#
#    std_average_daily_clients_last_1/6_months  \
# 0                                       0.50
# 1                                       0.00
#
#    std_average_daily_clients_last_1/3_months  \
# 0                                       1.00
# 1                                       0.00
#
#    std_average_daily_clients_last_3/6_months
# 0                                       0.50
# 1                                       0.00

# %%
data1.fillna(-4, inplace = True)

data1.replace([np.inf, -np.inf], 0, inplace = True)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2607087288.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-4' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   data1.fillna(-4, inplace = True)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2607087288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.fillna(-4, inplace = True)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2607087288.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.replace([np.inf, -np.inf], 0, inplace = True)

# %%
data1.describe().T
# Out:
#                                                        count      mean  \
# kyc_business_type                                  342872.00     -4.00
# kyc_first_name_2                                   342872.00     -4.00
# kyc_last_name_2                                    342872.00     -4.00
# MOM_momo_TransactionsPerDay                        342872.00     -0.82
# MOM_momo_PAYMENT_QTY_6M                            342872.00     15.89
# MOM_momo_PAYMENT_QTY_3M                            342872.00      7.93
# MOM_momo_PAYMENT_QTY_1M                            342872.00      2.08
# MOM_momo_PAYMENT_QTY_1D                            342872.00     -1.90
# MOM_momo_PAYMENT_AMT_6M                            342872.00 914242.54
# MOM_momo_PAYMENT_AMT_3M                            342872.00 512377.23
# DAY_momo_PAYMENT_AMT                               342872.00   6584.93
# MOM_momo_PAYMENT_ACCEPTORS_6M                      342872.00      6.34
# MOM_momo_PAYMENT_ACCEPTORS_3M                      342872.00      3.07
# MOM_momo_PAYMENT_ACCEPTORS_1M                      342872.00      0.12
# DAY_momo_PAYMENT_ACCEPTORS                         342872.00     -1.93
# MOM_momo_PAYMENT_MAX_AMT_6M                        342872.00  63140.62
# MOM_momo_PAYMENT_MAX_AMT_3M                        342872.00  48320.05
# MOM_momo_PAYMENT_MAX_AMT_1M                        342872.00  27117.87
# DAY_momo_PAYMENT_MAX_AMT                           342872.00   3784.67
# MOM_momo_Withdrawal                                342872.00     -1.26
# MOM_momo_Till_Wallet_QTY_6M                        342872.00      1.19
# MOM_momo_Till_Wallet_QTY_3M                        342872.00     -0.71
# MOM_momo_Till_Wallet_QTY_1M                        342872.00     -2.21
# DAY_momo_Till_Wallet_QTY                           342872.00     -3.08
# MOM_momo_Till_Bank_QTY_6M                          342872.00     -4.00
# MOM_momo_Till_Bank_QTY_3M                          342872.00     -4.00
# MOM_momo_Till_Bank_QTY_1M                          342872.00     -4.00
# DAY_momo_Till_Bank_QTY                             342872.00     -4.00
# MOM_momo_Till_Wallet_AMT_6M                        342872.00 772471.96
# MOM_momo_Till_Wallet_AMT_3M                        342872.00 424038.22
# MOM_momo_Till_Wallet_AMT_1M                        342872.00 157201.65
# DAY_momo_Till_Wallet_AMT                           342872.00   5509.54
# MOM_momo_Till_Bank_AMT_6M                          342872.00     -1.26
# MOM_momo_Till_Bank_AMT_3M                          342872.00     -1.58
# MOM_momo_Till_Bank_AMT_1M                          342872.00     -1.58
# DAY_momo_Till_Bank_AMT                             342872.00     -3.72
# MOM_momo_m2m_PAYMENT_QTY_6M                        342872.00     -2.04
# MOM_momo_m2m_PAYMENT_QTY_3M                        342872.00     -2.55
# MOM_momo_m2m_PAYMENT_QTY_1M                        342872.00     -2.91
# DAY_momo_m2m_PAYMENT_QTY                           342872.00     -3.13
# MOM_momo_m2m_PAYMENT_AMT_6M                        342872.00  39090.58
# MOM_momo_m2m_PAYMENT_AMT_3M                        342872.00  28962.50
# MOM_momo_m2m_PAYMENT_AMT_1M                        342872.00   7725.09
# DAY_momo_m2m_PAYMENT_AMT                           342872.00    271.11
# MOMO_No_Activity_QTY_6M                            342872.00     81.19
# MOMO_No_Activity_QTY_3M                            342872.00     23.71
# MOMO_No_Activity_QTY_1M                            342872.00      1.67
# age_on_network_months                              342872.00     30.06
# months_since_first_activity                        342872.00      4.37
# days_since_first_activity                          342872.00    182.19
# days_btwn_joining_and_first_activity_date          342872.00    452.23
# days_since_last_pay_in                             342872.00     29.03
# days_since_last_payout_to_mobile_money             342872.00      8.36
# days_since_last_payout_to_bank                     342872.00     -4.00
# trading_consistency                                342872.00     -1.98
# average_daily_transacted_amount_last_6_months      342872.00   5028.18
# average_daily_transacted_amount_last_3_months      342872.00   5874.83
# average_daily_transacted_amount_last_1_months      342872.00     -2.46
# ratio_average_daily_transacted_amount_last_1/6_... 342872.00     -3.95
# ratio_average_daily_transacted_amount_last_1/3_... 342872.00     -3.92
# ratio_average_daily_transacted_amount_last_3/6_... 342872.00     -3.20
# std_average_daily_transacted_amount_last_1/6_mo... 342872.00      9.53
# std_average_daily_transacted_amount_last_1/3_mo... 342872.00      7.61
# std_average_daily_transacted_amount_last_3/6_mo... 342872.00    546.74
# average_transaction_size_last_6_months             342872.00  10363.39
# average_transaction_size_last_3_months             342872.00  12352.45
# average_transaction_size_last_1_months             342872.00      6.31
# ratio_average_trxn_size_last_1/6_months            342872.00     -3.04
# ratio_average_trxn_size_last_1/3_months            342872.00     -2.60
# ratio_average_trxn_size_last_3/6_months            342872.00     -2.52
# std_average_trxn_size_last_1/6_months              342872.00   2611.73
# std_average_trxn_size_last_1/3_months              342872.00   2749.22
# std_average_trxn_size_last_3/6_months              342872.00   3037.88
# count_of_transactions_last_6_months                342872.00     13.36
# count_of_transactions_last_3_months                342872.00      7.13
# count_of_transactions_last_1_months                342872.00      2.08
# average_daily_transactions_last_6_months           342872.00     -1.15
# average_daily_transactions_last_3_months           342872.00     -1.21
# average_daily_transactions_last_1_months           342872.00     -1.20
# ratio_average_daily_transactions_last_1/6_months   342872.00     -0.29
# ratio_average_daily_transactions_last_1/3_months   342872.00     -0.68
# ratio_average_daily_transactions_last_3/6_months   342872.00     -0.21
# std_average_daily_transactions_last_1/6_months     342872.00      0.14
# std_average_daily_transactions_last_1/3_months     342872.00      0.14
# std_average_daily_transactions_last_3/6_months     342872.00      0.14
# count_of_clients_last_6_months                     342872.00      4.67
# count_of_clients_last_3_months                     342872.00      2.54
# count_of_clients_last_1_months                     342872.00      0.12
# average_daily_clients_last_6_months                342872.00     -2.35
# average_daily_clients_last_3_months                342872.00     -2.32
# average_daily_clients_last_1_months                342872.00     -1.82
# ratio_average_daily_clients_last_1/6_months        342872.00     -2.61
# ratio_average_daily_clients_last_1/3_months        342872.00     -2.62
# ratio_average_daily_clients_last_3/6_months        342872.00     -2.36
# std_average_daily_clients_last_1/6_months          342872.00      0.13
# std_average_daily_clients_last_1/3_months          342872.00      0.14
# std_average_daily_clients_last_3/6_months          342872.00     -2.68
#
#                                                            std      min   25%  \
# kyc_business_type                                         0.00    -4.00 -4.00
# kyc_first_name_2                                          0.00    -4.00 -4.00
# kyc_last_name_2                                           0.00    -4.00 -4.00
# MOM_momo_TransactionsPerDay                               6.08    -4.00 -4.00
# MOM_momo_PAYMENT_QTY_6M                                 214.83    -4.00 -4.00
# MOM_momo_PAYMENT_QTY_3M                                  94.64    -4.00 -4.00
# MOM_momo_PAYMENT_QTY_1M                                  41.94    -4.00 -4.00
# MOM_momo_PAYMENT_QTY_1D                                   3.26    -4.00 -4.00
# MOM_momo_PAYMENT_AMT_6M                            14124882.99     1.00  1.00
# MOM_momo_PAYMENT_AMT_3M                             7582979.89    -4.00 -4.00
# DAY_momo_PAYMENT_AMT                                 129724.39    -4.00 -4.00
# MOM_momo_PAYMENT_ACCEPTORS_6M                            62.31    -4.00 -4.00
# MOM_momo_PAYMENT_ACCEPTORS_3M                            38.99    -4.00 -4.00
# MOM_momo_PAYMENT_ACCEPTORS_1M                            16.75    -4.00 -4.00
# DAY_momo_PAYMENT_ACCEPTORS                                2.33    -4.00 -4.00
# MOM_momo_PAYMENT_MAX_AMT_6M                          330566.68    -4.00 -4.00
# MOM_momo_PAYMENT_MAX_AMT_3M                          283220.50    -4.00 -4.00
# MOM_momo_PAYMENT_MAX_AMT_1M                          214135.90    -4.00 -4.00
# DAY_momo_PAYMENT_MAX_AMT                              70791.22    -4.00 -4.00
# MOM_momo_Withdrawal                                    1254.90    -4.00 -4.00
# MOM_momo_Till_Wallet_QTY_6M                              31.17    -4.00 -4.00
# MOM_momo_Till_Wallet_QTY_3M                              17.38    -4.00 -4.00
# MOM_momo_Till_Wallet_QTY_1M                               7.46    -4.00 -4.00
# DAY_momo_Till_Wallet_QTY                                  1.75    -4.00 -4.00
# MOM_momo_Till_Bank_QTY_6M                                 0.02    -4.00 -4.00
# MOM_momo_Till_Bank_QTY_3M                                 0.02    -4.00 -4.00
# MOM_momo_Till_Bank_QTY_1M                                 0.02    -4.00 -4.00
# DAY_momo_Till_Bank_QTY                                    0.01    -4.00 -4.00
# MOM_momo_Till_Wallet_AMT_6M                        12823500.72    -4.00 -4.00
# MOM_momo_Till_Wallet_AMT_3M                         6830433.76    -4.00 -4.00
# MOM_momo_Till_Wallet_AMT_1M                         2473580.41    -4.00 -4.00
# DAY_momo_Till_Wallet_AMT                             126983.94    -4.00 -4.00
# MOM_momo_Till_Bank_AMT_6M                              1254.90    -4.00 -4.00
# MOM_momo_Till_Bank_AMT_3M                              1240.76    -4.00 -4.00
# MOM_momo_Till_Bank_AMT_1M                              1240.76    -4.00 -4.00
# DAY_momo_Till_Bank_AMT                                  163.95    -4.00 -4.00
# MOM_momo_m2m_PAYMENT_QTY_6M                               8.96    -4.00 -4.00
# MOM_momo_m2m_PAYMENT_QTY_3M                               5.38    -4.00 -4.00
# MOM_momo_m2m_PAYMENT_QTY_1M                               2.78    -4.00 -4.00
# DAY_momo_m2m_PAYMENT_QTY                                  1.67    -4.00 -4.00
# MOM_momo_m2m_PAYMENT_AMT_6M                          765889.71    -4.00 -4.00
# MOM_momo_m2m_PAYMENT_AMT_3M                          575311.35    -4.00 -4.00
# MOM_momo_m2m_PAYMENT_AMT_1M                          227815.70    -4.00 -4.00
# DAY_momo_m2m_PAYMENT_AMT                              17643.23    -4.00 -4.00
# MOMO_No_Activity_QTY_6M                                  88.58    -4.00 -4.00
# MOMO_No_Activity_QTY_3M                                  41.03    -4.00 -4.00
# MOMO_No_Activity_QTY_1M                                  11.84    -4.00 -4.00
# age_on_network_months                                    33.07    -4.00 -4.00
# months_since_first_activity                              11.21    -4.00 -4.00
# days_since_first_activity                               311.16     0.00  1.00
# days_btwn_joining_and_first_activity_date               770.38 -1233.00 -4.00
# days_since_last_pay_in                                   51.80    -4.00 -4.00
# days_since_last_payout_to_mobile_money                   33.66    -4.00 -4.00
# days_since_last_payout_to_bank                            0.27    -4.00 -4.00
# trading_consistency                                       2.06    -4.00 -4.00
# average_daily_transacted_amount_last_6_months         80424.32    -4.00 -4.00
# average_daily_transacted_amount_last_3_months         85593.54    -4.00 -4.00
# average_daily_transacted_amount_last_1_months            17.04    -4.00 -4.00
# ratio_average_daily_transacted_amount_last_1/6_...        0.54    -4.00 -4.00
# ratio_average_daily_transacted_amount_last_1/3_...        0.66    -4.00 -4.00
# ratio_average_daily_transacted_amount_last_3/6_...        1.85    -4.00 -4.00
# std_average_daily_transacted_amount_last_1/6_mo...     1206.06    -4.00 -4.00
# std_average_daily_transacted_amount_last_1/3_mo...      476.64    -4.00 -4.00
# std_average_daily_transacted_amount_last_3/6_mo...     9963.42    -4.00 -4.00
# average_transaction_size_last_6_months                75328.98    -4.00 -4.00
# average_transaction_size_last_3_months                81560.62    -4.00 -4.00
# average_transaction_size_last_1_months                   64.62    -4.00 -4.00
# ratio_average_trxn_size_last_1/6_months                   1.70    -4.00 -4.00
# ratio_average_trxn_size_last_1/3_months                   2.12    -4.00 -4.00
# ratio_average_trxn_size_last_3/6_months                   2.26    -4.00 -4.00
# std_average_trxn_size_last_1/6_months                 28468.22    -4.00 -4.00
# std_average_trxn_size_last_1/3_months                 27199.91    -4.00 -4.00
# std_average_trxn_size_last_3/6_months                 28223.92    -4.00 -4.00
# count_of_transactions_last_6_months                     213.73    -4.00 -4.00
# count_of_transactions_last_3_months                      93.56    -4.00 -4.00
# count_of_transactions_last_1_months                      41.94    -4.00 -4.00
# average_daily_transactions_last_6_months                  2.60    -4.00 -4.00
# average_daily_transactions_last_3_months                  2.48    -4.00 -4.00
# average_daily_transactions_last_1_months                  2.83    -4.00 -4.00
# ratio_average_daily_transactions_last_1/6_months          1.92  -231.00  0.00
# ratio_average_daily_transactions_last_1/3_months          2.24  -231.00 -4.00
# ratio_average_daily_transactions_last_3/6_months          1.88    -4.00  0.00
# std_average_daily_transactions_last_1/6_months            0.73     0.00  0.00
# std_average_daily_transactions_last_1/3_months            0.73     0.00  0.00
# std_average_daily_transactions_last_3/6_months            0.44     0.00  0.00
# count_of_clients_last_6_months                           61.79    -4.00 -4.00
# count_of_clients_last_3_months                           38.93    -4.00 -4.00
# count_of_clients_last_1_months                           16.75    -4.00 -4.00
# average_daily_clients_last_6_months                       2.40    -4.00 -4.00
# average_daily_clients_last_3_months                       2.50    -4.00 -4.00
# average_daily_clients_last_1_months                       2.26    -4.00 -4.00
# ratio_average_daily_clients_last_1/6_months               2.02    -4.00 -4.00
# ratio_average_daily_clients_last_1/3_months               2.01    -4.00 -4.00
# ratio_average_daily_clients_last_3/6_months               2.36    -4.00 -4.00
# std_average_daily_clients_last_1/6_months                 0.26     0.00  0.00
# std_average_daily_clients_last_1/3_months                 0.37     0.00  0.00
# std_average_daily_clients_last_3/6_months                 1.90    -4.00 -4.00
#
#                                                      50%      75%  \
# kyc_business_type                                  -4.00    -4.00
# kyc_first_name_2                                   -4.00    -4.00
# kyc_last_name_2                                    -4.00    -4.00
# MOM_momo_TransactionsPerDay                        -4.00     1.00
# MOM_momo_PAYMENT_QTY_6M                            -4.00     5.00
# MOM_momo_PAYMENT_QTY_3M                            -4.00     1.00
# MOM_momo_PAYMENT_QTY_1M                            -4.00     0.00
# MOM_momo_PAYMENT_QTY_1D                            -4.00     0.00
# MOM_momo_PAYMENT_AMT_6M                             1.00 30000.00
# MOM_momo_PAYMENT_AMT_3M                            -4.00  1500.00
# DAY_momo_PAYMENT_AMT                               -4.00    -4.00
# MOM_momo_PAYMENT_ACCEPTORS_6M                      -4.00     2.00
# MOM_momo_PAYMENT_ACCEPTORS_3M                      -4.00     1.00
# MOM_momo_PAYMENT_ACCEPTORS_1M                      -4.00     0.00
# DAY_momo_PAYMENT_ACCEPTORS                         -4.00     0.00
# MOM_momo_PAYMENT_MAX_AMT_6M                        -4.00 10500.00
# MOM_momo_PAYMENT_MAX_AMT_3M                        -4.00  1000.00
# MOM_momo_PAYMENT_MAX_AMT_1M                        -4.00    -4.00
# DAY_momo_PAYMENT_MAX_AMT                           -4.00    -4.00
# MOM_momo_Withdrawal                                -4.00    -4.00
# MOM_momo_Till_Wallet_QTY_6M                        -4.00    -4.00
# MOM_momo_Till_Wallet_QTY_3M                        -4.00    -4.00
# MOM_momo_Till_Wallet_QTY_1M                        -4.00    -4.00
# DAY_momo_Till_Wallet_QTY                           -4.00    -4.00
# MOM_momo_Till_Bank_QTY_6M                          -4.00    -4.00
# MOM_momo_Till_Bank_QTY_3M                          -4.00    -4.00
# MOM_momo_Till_Bank_QTY_1M                          -4.00    -4.00
# DAY_momo_Till_Bank_QTY                             -4.00    -4.00
# MOM_momo_Till_Wallet_AMT_6M                        -4.00    -4.00
# MOM_momo_Till_Wallet_AMT_3M                        -4.00    -4.00
# MOM_momo_Till_Wallet_AMT_1M                        -4.00    -4.00
# DAY_momo_Till_Wallet_AMT                           -4.00    -4.00
# MOM_momo_Till_Bank_AMT_6M                          -4.00    -4.00
# MOM_momo_Till_Bank_AMT_3M                          -4.00    -4.00
# MOM_momo_Till_Bank_AMT_1M                          -4.00    -4.00
# DAY_momo_Till_Bank_AMT                             -4.00    -4.00
# MOM_momo_m2m_PAYMENT_QTY_6M                        -4.00    -4.00
# MOM_momo_m2m_PAYMENT_QTY_3M                        -4.00    -4.00
# MOM_momo_m2m_PAYMENT_QTY_1M                        -4.00    -4.00
# DAY_momo_m2m_PAYMENT_QTY                           -4.00    -4.00
# MOM_momo_m2m_PAYMENT_AMT_6M                        -4.00    -4.00
# MOM_momo_m2m_PAYMENT_AMT_3M                        -4.00    -4.00
# MOM_momo_m2m_PAYMENT_AMT_1M                        -4.00    -4.00
# DAY_momo_m2m_PAYMENT_AMT                           -4.00    -4.00
# MOMO_No_Activity_QTY_6M                            -4.00   178.00
# MOMO_No_Activity_QTY_3M                            -4.00    83.00
# MOMO_No_Activity_QTY_1M                            -4.00    -4.00
# age_on_network_months                              22.00    54.00
# months_since_first_activity                         2.00     7.00
# days_since_first_activity                          56.00   205.00
# days_btwn_joining_and_first_activity_date          -4.00   685.00
# days_since_last_pay_in                             -4.00    48.00
# days_since_last_payout_to_mobile_money             -4.00    -4.00
# days_since_last_payout_to_bank                     -4.00    -4.00
# trading_consistency                                -4.00     0.02
# average_daily_transacted_amount_last_6_months      -4.00     4.95
# average_daily_transacted_amount_last_3_months      -4.00     0.68
# average_daily_transacted_amount_last_1_months      -4.00    -4.00
# ratio_average_daily_transacted_amount_last_1/6_... -4.00    -4.00
# ratio_average_daily_transacted_amount_last_1/3_... -4.00    -4.00
# ratio_average_daily_transacted_amount_last_3/6_... -4.00    -4.00
# std_average_daily_transacted_amount_last_1/6_mo... -4.00     0.00
# std_average_daily_transacted_amount_last_1/3_mo... -4.00     0.00
# std_average_daily_transacted_amount_last_3/6_mo...  0.00     0.00
# average_transaction_size_last_6_months             -4.00   500.00
# average_transaction_size_last_3_months             -4.00    50.00
# average_transaction_size_last_1_months             -4.00    -4.00
# ratio_average_trxn_size_last_1/6_months            -4.00    -4.00
# ratio_average_trxn_size_last_1/3_months            -4.00     0.00
# ratio_average_trxn_size_last_3/6_months            -4.00     0.00
# std_average_trxn_size_last_1/6_months              -4.00     0.00
# std_average_trxn_size_last_1/3_months              -4.00     0.00
# std_average_trxn_size_last_3/6_months              -4.00   102.00
# count_of_transactions_last_6_months                -4.00     1.00
# count_of_transactions_last_3_months                -4.00     1.00
# count_of_transactions_last_1_months                -4.00     0.00
# average_daily_transactions_last_6_months           -0.00     1.00
# average_daily_transactions_last_3_months           -0.00     1.00
# average_daily_transactions_last_1_months            0.00     0.00
# ratio_average_daily_transactions_last_1/6_months    0.00     1.00
# ratio_average_daily_transactions_last_1/3_months    1.00     1.00
# ratio_average_daily_transactions_last_3/6_months    1.00     1.00
# std_average_daily_transactions_last_1/6_months      0.00     0.00
# std_average_daily_transactions_last_1/3_months      0.00     0.00
# std_average_daily_transactions_last_3/6_months      0.00     0.50
# count_of_clients_last_6_months                     -4.00     1.00
# count_of_clients_last_3_months                     -4.00     1.00
# count_of_clients_last_1_months                     -4.00     0.00
# average_daily_clients_last_6_months                -4.00     1.00
# average_daily_clients_last_3_months                -4.00     1.00
# average_daily_clients_last_1_months                -4.00     0.00
# ratio_average_daily_clients_last_1/6_months        -4.00     0.00
# ratio_average_daily_clients_last_1/3_months        -4.00     0.00
# ratio_average_daily_clients_last_3/6_months        -4.00     1.00
# std_average_daily_clients_last_1/6_months           0.00     0.00
# std_average_daily_clients_last_1/3_months           0.00     0.00
# std_average_daily_clients_last_3/6_months          -4.00     0.00
#
#                                                              max
# kyc_business_type                                          -4.00
# kyc_first_name_2                                           -4.00
# kyc_last_name_2                                            -4.00
# MOM_momo_TransactionsPerDay                              1323.00
# MOM_momo_PAYMENT_QTY_6M                                 60010.00
# MOM_momo_PAYMENT_QTY_3M                                 19708.00
# MOM_momo_PAYMENT_QTY_1M                                  6196.00
# MOM_momo_PAYMENT_QTY_1D                                   633.00
# MOM_momo_PAYMENT_AMT_6M                            2001235267.00
# MOM_momo_PAYMENT_AMT_3M                             994836387.00
# DAY_momo_PAYMENT_AMT                                 15730000.00
# MOM_momo_PAYMENT_ACCEPTORS_6M                            7647.00
# MOM_momo_PAYMENT_ACCEPTORS_3M                            5490.00
# MOM_momo_PAYMENT_ACCEPTORS_1M                            2472.00
# DAY_momo_PAYMENT_ACCEPTORS                                129.00
# MOM_momo_PAYMENT_MAX_AMT_6M                          15000000.00
# MOM_momo_PAYMENT_MAX_AMT_3M                          15000000.00
# MOM_momo_PAYMENT_MAX_AMT_1M                          12000000.00
# DAY_momo_PAYMENT_MAX_AMT                              5000000.00
# MOM_momo_Withdrawal                                    720000.00
# MOM_momo_Till_Wallet_QTY_6M                              4522.00
# MOM_momo_Till_Wallet_QTY_3M                              1906.00
# MOM_momo_Till_Wallet_QTY_1M                               561.00
# DAY_momo_Till_Wallet_QTY                                   61.00
# MOM_momo_Till_Bank_QTY_6M                                   2.00
# MOM_momo_Till_Bank_QTY_3M                                   2.00
# MOM_momo_Till_Bank_QTY_1M                                   2.00
# DAY_momo_Till_Bank_QTY                                      1.00
# MOM_momo_Till_Wallet_AMT_6M                        1999405677.00
# MOM_momo_Till_Wallet_AMT_3M                         895350000.00
# MOM_momo_Till_Wallet_AMT_1M                         281550000.00
# DAY_momo_Till_Wallet_AMT                             14136800.00
# MOM_momo_Till_Bank_AMT_6M                              720000.00
# MOM_momo_Till_Bank_AMT_3M                              720000.00
# MOM_momo_Till_Bank_AMT_1M                              720000.00
# DAY_momo_Till_Bank_AMT                                  96000.00
# MOM_momo_m2m_PAYMENT_QTY_6M                               955.00
# MOM_momo_m2m_PAYMENT_QTY_3M                               440.00
# MOM_momo_m2m_PAYMENT_QTY_1M                               270.00
# DAY_momo_m2m_PAYMENT_QTY                                   13.00
# MOM_momo_m2m_PAYMENT_AMT_6M                         212765000.00
# MOM_momo_m2m_PAYMENT_AMT_3M                         143193500.00
# MOM_momo_m2m_PAYMENT_AMT_1M                          75338000.00
# DAY_momo_m2m_PAYMENT_AMT                              4000000.00
# MOMO_No_Activity_QTY_6M                                   179.00
# MOMO_No_Activity_QTY_3M                                    89.00
# MOMO_No_Activity_QTY_1M                                    29.00
# age_on_network_months                                     109.00
# months_since_first_activity                                48.00
# days_since_first_activity                                1481.00
# days_btwn_joining_and_first_activity_date                3276.00
# days_since_last_pay_in                                    179.00
# days_since_last_payout_to_mobile_money                    179.00
# days_since_last_payout_to_bank                            152.00
# trading_consistency                                         2.00
# average_daily_transacted_amount_last_6_months        11117973.71
# average_daily_transacted_amount_last_3_months        11053737.63
# average_daily_transacted_amount_last_1_months             800.00
# ratio_average_daily_transacted_amount_last_1/6_...          6.00
# ratio_average_daily_transacted_amount_last_1/3_...          3.00
# ratio_average_daily_transacted_amount_last_3/6_...          2.00
# std_average_daily_transacted_amount_last_1/6_mo...     620102.74
# std_average_daily_transacted_amount_last_1/3_mo...     147979.33
# std_average_daily_transacted_amount_last_3/6_mo...    1957085.88
# average_transaction_size_last_6_months               10000000.00
# average_transaction_size_last_3_months                5232476.19
# average_transaction_size_last_1_months                    996.00
# ratio_average_trxn_size_last_1/6_months                     4.00
# ratio_average_trxn_size_last_1/3_months                     5.33
# ratio_average_trxn_size_last_3/6_months                   195.68
# std_average_trxn_size_last_1/6_months                 5000002.00
# std_average_trxn_size_last_1/3_months                 2500002.00
# std_average_trxn_size_last_3/6_months                 5000002.00
# count_of_transactions_last_6_months                     60010.00
# count_of_transactions_last_3_months                     19708.00
# count_of_transactions_last_1_months                      6196.00
# average_daily_transactions_last_6_months                  334.00
# average_daily_transactions_last_3_months                  219.00
# average_daily_transactions_last_1_months                  262.00
# ratio_average_daily_transactions_last_1/6_months            6.00
# ratio_average_daily_transactions_last_1/3_months            3.00
# ratio_average_daily_transactions_last_3/6_months            2.00
# std_average_daily_transactions_last_1/6_months            131.00
# std_average_daily_transactions_last_1/3_months            131.00
# std_average_daily_transactions_last_3/6_months            155.50
# count_of_clients_last_6_months                           7647.00
# count_of_clients_last_3_months                           5490.00
# count_of_clients_last_1_months                           2472.00
# average_daily_clients_last_6_months                        53.00
# average_daily_clients_last_3_months                        85.00
# average_daily_clients_last_1_months                        39.00
# ratio_average_daily_clients_last_1/6_months                 1.00
# ratio_average_daily_clients_last_1/3_months                 1.00
# ratio_average_daily_clients_last_3/6_months                 2.00
# std_average_daily_clients_last_1/6_months                  18.50
# std_average_daily_clients_last_1/3_months                  39.50
# std_average_daily_clients_last_3/6_months                  21.00

# %%
first_data_cols=   ['kyc_merchant_code', 'kyc_momo_account_number',
       'MOM_momo_Till_Wallet_AMT_1M', 'DAY_momo_Till_Wallet_AMT',
       'MOM_momo_Till_Bank_AMT_6M', 'MOM_momo_Till_Bank_AMT_3M',
       'MOM_momo_Till_Bank_AMT_1M', 'DAY_momo_Till_Bank_AMT',
       'MOM_momo_m2m_PAYMENT_QTY_6M', 'MOM_momo_m2m_PAYMENT_QTY_3M',
       'MOM_momo_m2m_PAYMENT_QTY_1M', 'DAY_momo_m2m_PAYMENT_QTY',
       'MOM_momo_m2m_PAYMENT_AMT_6M', 'MOM_momo_m2m_PAYMENT_AMT_3M',
       'MOM_momo_m2m_PAYMENT_AMT_1M', 'DAY_momo_m2m_PAYMENT_AMT',
       'MOMO_No_Activity_QTY_6M', 'MOMO_No_Activity_QTY_3M',
       'MOMO_No_Activity_QTY_1M', 'age_on_network_months',
       'months_since_first_activity', 'days_since_first_activity',
       'days_btwn_joining_and_first_activity_date', 'days_since_last_pay_in',
       'days_since_last_payout_to_mobile_money',
       'days_since_last_payout_to_bank', 'trading_consistency',
       'average_daily_transacted_amount_last_6_months',
       'average_daily_transacted_amount_last_3_months',
       'average_daily_transacted_amount_last_1_months',
       'ratio_average_daily_transacted_amount_last_1/6_months',
       'ratio_average_daily_transacted_amount_last_1/3_months',
       'ratio_average_daily_transacted_amount_last_3/6_months',
       'std_average_daily_transacted_amount_last_1/6_months',
       'std_average_daily_transacted_amount_last_1/3_months',
       'std_average_daily_transacted_amount_last_3/6_months',
       'average_transaction_size_last_6_months',
       'average_transaction_size_last_3_months',
       'average_transaction_size_last_1_months',
       'ratio_average_trxn_size_last_1/6_months',
       'ratio_average_trxn_size_last_1/3_months',
       'ratio_average_trxn_size_last_3/6_months',
       'std_average_trxn_size_last_1/6_months',
       'std_average_trxn_size_last_1/3_months',
       'std_average_trxn_size_last_3/6_months',
       'count_of_transactions_last_6_months',
       'count_of_transactions_last_3_months',
       'count_of_transactions_last_1_months',
       'average_daily_transactions_last_6_months',
       'average_daily_transactions_last_3_months',
       'average_daily_transactions_last_1_months',
       'ratio_average_daily_transactions_last_1/6_months',
       'ratio_average_daily_transactions_last_1/3_months',
       'ratio_average_daily_transactions_last_3/6_months',
       'trading_consistency_score', 'age_on_network_score',
       'days_since_last_transaction_score',
       'ratio_average_daily_transacted_amount_score',
       'ratio_average_trxn_size_score', 'total_score', 'all_loans',
       'repayments', 'loan_band', 'repayments_band',
       'twenty_one_day_limit_factor', 'seven_day_limit_factor',
       'one_day_limit_factor', 'minimum_21_day_limit_on_6_months',
       'minimum_7_day_limit_on_6_months', 'minimum_1_day_limit_on_6_months',
       'rounded_21_day_limit_on_6_months', 'rounded_7_day_limit_on_6_months',
       'rounded_1_day_limit_on_6_months', 'final_21_day_limit_on_6_months',
       'final_7_day_limit_on_6_months_200_min',
       'final_1_day_limit_on_6_months', 'pilot_final_21_day_limit_on_6_months',
       'pilot_final_7_day_limit_on_6_months',
       'pilot_final_1_day_limit_on_6_months']

# %% [markdown]
# ### Beginning of modelling

# %%
data1_derived_df = data1.iloc[ : , list(range(0,2)) + list(range(47,99))]

data1_derived_df.head(2)
# Out:
#   kyc_merchant_code                      id_number_ah  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                   -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                        -4.00                     -4.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                   -4.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                          -4.00
# 1                                          -4.00
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                   -4.00
# 1                                   -4.00
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
#
#    count_of_clients_last_6_months
# 0                          191.00
# 1                           32.00

# %%
# data1_derived_df.shape
data1.shape
# Out:
# (342872, 110)

# %%
# df_encoded_data1 =data1_derived_df
# df_encoded_data1.shape
df_encoded_data1=data1

# %% [markdown]
# ### Heuristic Model

# %% [markdown]
# #### Trading consistency

# %%
def trading_consistency_score(df):
    
    trading_consistency = df['trading_consistency']
    
    if trading_consistency < .30:
        return -50
    elif trading_consistency >= .30 and trading_consistency < .40:
        return -25
    elif trading_consistency >= .40 and trading_consistency < .50:
        return 0
    elif trading_consistency >= .50 and trading_consistency < .60:
        return 100
    elif trading_consistency >= .60 and trading_consistency < .70:
        return 125
    elif trading_consistency >= .70 and trading_consistency < .95:
        return 150
    elif trading_consistency >= .95:
        return 200

# %%
df_encoded_data1['trading_consistency_score'] = df_encoded_data1.apply(lambda x : trading_consistency_score(x), axis = 1)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2541503455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['trading_consistency_score'] = df_encoded_data1.apply(lambda x : trading_consistency_score(x), axis = 1)

# %% [markdown]
# #### Age on network

# %%
# defining a function to score for age on network

def age_on_network_score(df):
    age = df['months_since_first_activity']
    
    if age >= 0 and age < 1 :
        return -100
    if age >= 1 and age < 3:
        return 0
    elif age >= 3 and age < 4:
        return 50
    elif age >= 4 and age < 5:
        return 100
    elif age >= 5:
        return 200

# %%
df_encoded_data1['age_on_network_score'] = df_encoded_data1.apply(lambda x : age_on_network_score(x), axis = 1)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\4003455338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['age_on_network_score'] = df_encoded_data1.apply(lambda x : age_on_network_score(x), axis = 1)

# %% [markdown]
# #### Days since last transaction

# %%
def days_since_last_transaction_score(df):
    
    days_since = df['days_since_last_pay_in']
    
    if days_since <= 5:
        return 200
    elif days_since > 5 and days_since <= 7:
        return 150
    elif days_since > 7 and days_since <= 10:
        return 125
    elif days_since > 10 and days_since <= 15:
        return 100
    elif days_since > 15 and days_since <=20:
        return 50
    elif days_since > 20 and days_since <= 30:
        return 0
    elif days_since > 30:
        return -50

# %%
df_encoded_data1['days_since_last_transaction_score'] = df_encoded_data1.apply(lambda x : days_since_last_transaction_score(x), axis = 1)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3591660777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['days_since_last_transaction_score'] = df_encoded_data1.apply(lambda x : days_since_last_transaction_score(x), axis = 1)

# %% [markdown]
# #### Ratio average daily transacted amount last 1/3 months

# %%
def ratio_average_daily_transacted_amount_last_1_3_months(df):
    
    ratio = df['ratio_average_daily_transacted_amount_last_1/3_months']
    
    if ratio < .10:
        return -50
    elif ratio >= .10 and ratio < .30:
        return -25
    elif ratio >= .30 and ratio < .40:
        return 0
    elif ratio >= .40 and ratio < .50:
        return 50
    elif ratio >= .50 and ratio < .70:
        return 100
    elif ratio >= .70 and ratio < .80:
        return 125
    elif ratio >= .80 and ratio < .90:
        return 150
    elif ratio >= .90 and ratio < 1.1:
        return 175
    elif ratio >= 1.1:
        return 200

# %%
df_encoded_data1['ratio_average_daily_transacted_amount_score'] = df_encoded_data1.apply(lambda x : ratio_average_daily_transacted_amount_last_1_3_months(x), axis = 1)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1878188590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['ratio_average_daily_transacted_amount_score'] = df_encoded_data1.apply(lambda x : ratio_average_daily_transacted_amount_last_1_3_months(x), axis = 1)

# %% [markdown]
# #### Ratio average transaction size last 1/3 months

# %%
def ratio_average_transaction_size_last_1_3_months(df):
    
    ratio = df['ratio_average_trxn_size_last_1/3_months']
    
    if ratio < .10:
        return -50
    elif ratio >= .10 and ratio < .30:
        return -25
    elif ratio >= .30 and ratio < .40:
        return 0
    elif ratio >= .40 and ratio < .50:
        return 50
    elif ratio >= .50 and ratio < .70:
        return 100
    elif ratio >= .70 and ratio < .80:
        return 125
    elif ratio >= .80 and ratio < .90:
        return 150
    elif ratio >= .90 and ratio < 1.1:
        return 175
    elif ratio >= 1.1:
        return 200

# %%
df_encoded_data1['ratio_average_trxn_size_score'] = df_encoded_data1.apply(lambda x : ratio_average_transaction_size_last_1_3_months(x), axis = 1)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1039886935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['ratio_average_trxn_size_score'] = df_encoded_data1.apply(lambda x : ratio_average_transaction_size_last_1_3_months(x), axis = 1)

# %%
## combine scores

df_encoded_data1['total_score'] = df_encoded_data1[['trading_consistency_score','ratio_average_daily_transacted_amount_score','age_on_network_score',
                                                'ratio_average_trxn_size_score','days_since_last_transaction_score']].sum(axis = 1)

df_encoded_data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\4026240741.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['total_score'] = df_encoded_data1[['trading_consistency_score','ratio_average_daily_transacted_amount_score','age_on_network_score',
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN              -4.00         -4             -4.00
# 1        NRIN              -4.00         -4             -4.00
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0            -4.00   2023-01-21 00:00:00  MTNU MoMoPay Informal
# 1            -4.00   2017-10-17 00:00:00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                              -4
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                   -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                        -4.00                     -4.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                   -4.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                          -4.00
# 1                                          -4.00
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                   -4.00
# 1                                   -4.00
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
#
#    ratio_average_daily_clients_last_3/6_months  \
# 0                                         1.50
# 1                                         1.00
#
#    std_average_daily_clients_last_1/6_months  \
# 0                                       0.50
# 1                                       0.00
#
#    std_average_daily_clients_last_1/3_months  \
# 0                                       1.00
# 1                                       0.00
#
#    std_average_daily_clients_last_3/6_months  trading_consistency_score  \
# 0                                       0.50                        -25
# 1                                       0.00                        -50
#
#    age_on_network_score  days_since_last_transaction_score  \
# 0                200.00                                200
# 1                200.00                                200
#
#    ratio_average_daily_transacted_amount_score  ratio_average_trxn_size_score  \
# 0                                          -50                            -50
# 1                                          -50                            -50
#
#    total_score
# 0       275.00
# 1       250.00

# %% [markdown]
# ### Limit Allocation

# %%
## Assumptions for pilot period only, will need to be calculated fields once product is set up

df_encoded_data1['all_loans'] = 0

df_encoded_data1['repayments'] = 1
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3456996858.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['all_loans'] = 0
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3456996858.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['repayments'] = 1

# %%
def calculate_loan_count_bands(df):
    loan_count = df['all_loans']
    
    if loan_count == 0:
        return 'Band 1'
    elif loan_count >= 1 and loan_count <= 2:
        return 'Band 2'
    elif loan_count >= 3 and loan_count <= 5:
        return 'Band 3'
    elif loan_count >= 6 and loan_count <= 9:
        return 'Band 4'
    elif loan_count >= 10:
        return 'Band 5'

# %%
def calculate_repayments_bands(df):
    repayments = df['repayments']
    
    if repayments >= 0 and repayments <= 0.29:
        return 'Band 1'
    elif repayments >= 0.30 and repayments <= 0.49:
        return 'Band 2'
    elif repayments >= 0.50 and repayments <= 0.69:
        return 'Band 3'
    elif repayments >= 0.70 and repayments <= 0.89:
        return 'Band 4'
    elif repayments >= 0.90 and repayments <= 0.99:
        return 'Band 5'
    elif repayments >= 1.00:
        return 'Band 6'

# %%
df_encoded_data1['loan_band'] = df_encoded_data1.apply(lambda x : calculate_loan_count_bands(x), axis = 1)

df_encoded_data1['repayments_band'] = df_encoded_data1.apply(lambda x : calculate_repayments_bands(x), axis = 1)

df_encoded_data1.head(3)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3736050833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['loan_band'] = df_encoded_data1.apply(lambda x : calculate_loan_count_bands(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3736050833.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['repayments_band'] = df_encoded_data1.apply(lambda x : calculate_repayments_bands(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
# 2    169050@momopay  720E74A187312803EB76E049F9275199          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN              -4.00         -4             -4.00
# 1        NRIN              -4.00         -4             -4.00
# 2        NRIN              -4.00         -4             -4.00
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0            -4.00   2023-01-21 00:00:00  MTNU MoMoPay Informal
# 1            -4.00   2017-10-17 00:00:00  MTNU MoMoPay Informal
# 2            -4.00   2023-03-22 00:00:00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
# 2     2023-03-23 11:56:00                   2023-09-18 15:47:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                              -4
# 2                             2023-09-20 08:11:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
# 2                     2023-09-12 19:09:00                         8.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
# 2                   435.00                    21.00                    11.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
# 2                     0.00                 21762900               1600400.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
# 2               1,017,900                 -4.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
# 2                         371.00                          15.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
# 2                          10.00                        0.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
# 2                    500000.00                    463000.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
# 2                    463000.00                     -4.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
# 2        2023-09-18 15:47:00            720000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                        -4.00                        -4.00
# 2                        23.00                         8.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                        -4.00                     -4.00
# 2                         1.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
# 2                       2.00                       2.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
# 2                       2.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                        -4.00                        -4.00
# 2                  10292208.00                    601000.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                        -4.00                     -4.00
# 2                     50000.00                  50000.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
# 2                  720000.00                  720000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                   -4.00
# 2                  720000.00                   -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                        -4.00                        -4.00
# 2                         8.00                         5.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                        -4.00                     -4.00
# 2                         2.00                      0.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                        -4.00                        -4.00
# 2                    428800.00                    315000.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                        -4.00                     -4.00
# 2                     30000.00                     -4.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
# 2                   127.00                    74.00                    23.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
# 2                   7.00                         6.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
# 2                        182                                       1.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                   -4.00
# 2                    1.00                                   -0.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
# 2                            7.00                 0.29
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
# 2                                      120905.00
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
# 2                                       17782.22
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                          -4.00
# 1                                          -4.00
# 2                                          -4.00
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                              -4.00
# 1                                              -4.00
# 2                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                              -4.00
# 1                                              -4.00
# 2                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
# 2                                               0.15
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
# 2                                           51561.39
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
# 2                                50029.66
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
# 2                                76209.52
#
#    average_transaction_size_last_1_months  \
# 0                                   -4.00
# 1                                   -4.00
# 2                                   -4.00
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                    -4.00
# 1                                    -4.00
# 2                                    -4.00
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                    -4.00
# 1                                    -4.00
# 2                                    -4.00
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
# 2                                     1.52
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
# 2                               13089.93                               435.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
# 2                                21.00                                11.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
# 2                                      3.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
# 2                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
# 2                                            1.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
# 2                          371.00                           15.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
# 2                           10.00                                 3.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
# 2                                 5.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
# 2                                         0.33
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
# 2                                         0.20
#
#    ratio_average_daily_clients_last_3/6_months  \
# 0                                         1.50
# 1                                         1.00
# 2                                         1.67
#
#    std_average_daily_clients_last_1/6_months  \
# 0                                       0.50
# 1                                       0.00
# 2                                       1.00
#
#    std_average_daily_clients_last_1/3_months  \
# 0                                       1.00
# 1                                       0.00
# 2                                       2.00
#
#    std_average_daily_clients_last_3/6_months  trading_consistency_score  \
# 0                                       0.50                        -25
# 1                                       0.00                        -50
# 2                                       1.00                        -50
#
#    age_on_network_score  days_since_last_transaction_score  \
# 0                200.00                                200
# 1                200.00                                200
# 2                200.00                                200
#
#    ratio_average_daily_transacted_amount_score  ratio_average_trxn_size_score  \
# 0                                          -50                            -50
# 1                                          -50                            -50
# 2                                          -50                            -50
#
#    total_score  all_loans  repayments loan_band repayments_band
# 0       275.00          0           1    Band 1          Band 6
# 1       250.00          0           1    Band 1          Band 6
# 2       250.00          0           1    Band 1          Band 6

# %%
def calculate_21_day_limit_repayments_factor(df):
    """
    Input - loan band and repayment band
    
    Function - Calculate limit factor based on inputs (limit matrix)
    
    Output - Limit factor based on inputs
    
    """
    
    loan_band = df['loan_band']
    repayment_band = df['repayments_band'] ## repayment by end_rollover_date --> maximum achievable hurdle rates 
    
    
    if loan_band == 'Band 1':
        return 0.245
    elif loan_band == 'Band 2' and repayment_band == 'Band 4':
        return 0.203
    elif loan_band == 'Band 2' and repayment_band == 'Band 5':
        return 0.255
    elif loan_band == 'Band 2' and repayment_band == 'Band 6':
        return 0.263
    elif loan_band == 'Band 3' and repayment_band == 'Band 4':
        return 0.223
    elif loan_band == 'Band 3' and repayment_band == 'Band 5':
        return 0.275
    elif loan_band == 'Band 3' and repayment_band == 'Band 6':
        return 0.280
    elif loan_band == 'Band 4' and repayment_band == 'Band 4':
        return 0.243
    elif loan_band == 'Band 4' and repayment_band == 'Band 5':
        return 0.295
    elif loan_band == 'Band 4' and repayment_band == 'Band 6':
        return 0.298
    elif loan_band == 'Band 5' and repayment_band == 'Band 4':
        return 0.263
    elif loan_band == 'Band 5' and repayment_band == 'Band 5':
        return 0.315
    elif loan_band == 'Band 5' and repayment_band == 'Band 6':
        return 0.350
    else:
        return 0.0

# %%
def calculate_7_day_limit_repayments_factor(df):
    """
    Input - loan band and repayment band
    
    Function - Calculate limit factor based on inputs (limit matrix)
    
    Output - Limit factor based on inputs
    
    """
    
    loan_band = df['loan_band']
    repayment_band = df['repayments_band'] ## repayment by end_rollover_date --> maximum achievable hurdle rates 
    
    
    if loan_band == 'Band 1':
        return 0.119
    elif loan_band == 'Band 2' and repayment_band == 'Band 4':
        return 0.083
    elif loan_band == 'Band 2' and repayment_band == 'Band 5':
        return 0.108
    elif loan_band == 'Band 2' and repayment_band == 'Band 6':
        return 0.128
    elif loan_band == 'Band 3' and repayment_band == 'Band 4':
        return 0.098
    elif loan_band == 'Band 3' and repayment_band == 'Band 5':
        return 0.123
    elif loan_band == 'Band 3' and repayment_band == 'Band 6':
        return 0.136
    elif loan_band == 'Band 4' and repayment_band == 'Band 4':
        return 0.113
    elif loan_band == 'Band 4' and repayment_band == 'Band 5':
        return 0.138
    elif loan_band == 'Band 4' and repayment_band == 'Band 6':
        return 0.145
    elif loan_band == 'Band 5' and repayment_band == 'Band 4':
        return 0.128
    elif loan_band == 'Band 5' and repayment_band == 'Band 5':
        return 0.153
    elif loan_band == 'Band 5' and repayment_band == 'Band 6':
        return 0.170
    else:
        return 0.0

# %%
## for 1 day product 50% max of what is allocated for 7 day product

def calculate_1_day_limit_repayments_factor(df):
    """
    Input - seven_day_limit_factor
    
    Function - Calculate limit factor based on inputs (seven_day_limit_factor)
    
    Output - Limit factor based on inputs
    
    """
    
    seven_day_limit_factor = df['seven_day_limit_factor']
    
    
    one_day_limit_factor = round((seven_day_limit_factor / 2),3)
    
    
    return one_day_limit_factor

# %%
df_encoded_data1['twenty_one_day_limit_factor'] = df_encoded_data1.apply(lambda x : calculate_21_day_limit_repayments_factor(x), axis = 1)

df_encoded_data1['seven_day_limit_factor'] = df_encoded_data1.apply(lambda x : calculate_7_day_limit_repayments_factor(x), axis = 1)

df_encoded_data1['one_day_limit_factor'] = df_encoded_data1.apply(lambda x : calculate_1_day_limit_repayments_factor(x), axis = 1)

df_encoded_data1.head(3)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1736442842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['twenty_one_day_limit_factor'] = df_encoded_data1.apply(lambda x : calculate_21_day_limit_repayments_factor(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1736442842.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['seven_day_limit_factor'] = df_encoded_data1.apply(lambda x : calculate_7_day_limit_repayments_factor(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1736442842.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['one_day_limit_factor'] = df_encoded_data1.apply(lambda x : calculate_1_day_limit_repayments_factor(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
# 2    169050@momopay  720E74A187312803EB76E049F9275199          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN              -4.00         -4             -4.00
# 1        NRIN              -4.00         -4             -4.00
# 2        NRIN              -4.00         -4             -4.00
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0            -4.00   2023-01-21 00:00:00  MTNU MoMoPay Informal
# 1            -4.00   2017-10-17 00:00:00  MTNU MoMoPay Informal
# 2            -4.00   2023-03-22 00:00:00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
# 2     2023-03-23 11:56:00                   2023-09-18 15:47:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                              -4
# 2                             2023-09-20 08:11:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
# 2                     2023-09-12 19:09:00                         8.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
# 2                   435.00                    21.00                    11.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
# 2                     0.00                 21762900               1600400.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
# 2               1,017,900                 -4.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
# 2                         371.00                          15.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
# 2                          10.00                        0.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
# 2                    500000.00                    463000.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
# 2                    463000.00                     -4.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
# 2        2023-09-18 15:47:00            720000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                        -4.00                        -4.00
# 2                        23.00                         8.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                        -4.00                     -4.00
# 2                         1.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
# 2                       2.00                       2.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
# 2                       2.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                        -4.00                        -4.00
# 2                  10292208.00                    601000.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                        -4.00                     -4.00
# 2                     50000.00                  50000.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
# 2                  720000.00                  720000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                   -4.00
# 2                  720000.00                   -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                        -4.00                        -4.00
# 2                         8.00                         5.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                        -4.00                     -4.00
# 2                         2.00                      0.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                        -4.00                        -4.00
# 2                    428800.00                    315000.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                        -4.00                     -4.00
# 2                     30000.00                     -4.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
# 2                   127.00                    74.00                    23.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
# 2                   7.00                         6.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
# 2                        182                                       1.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                   -4.00
# 2                    1.00                                   -0.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
# 2                            7.00                 0.29
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
# 2                                      120905.00
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
# 2                                       17782.22
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                          -4.00
# 1                                          -4.00
# 2                                          -4.00
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                              -4.00
# 1                                              -4.00
# 2                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                              -4.00
# 1                                              -4.00
# 2                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
# 2                                               0.15
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
# 2                                           51561.39
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
# 2                                50029.66
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
# 2                                76209.52
#
#    average_transaction_size_last_1_months  \
# 0                                   -4.00
# 1                                   -4.00
# 2                                   -4.00
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                    -4.00
# 1                                    -4.00
# 2                                    -4.00
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                    -4.00
# 1                                    -4.00
# 2                                    -4.00
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
# 2                                     1.52
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
# 2                               13089.93                               435.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
# 2                                21.00                                11.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
# 2                                      3.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
# 2                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
# 2                                            1.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
# 2                          371.00                           15.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
# 2                           10.00                                 3.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
# 2                                 5.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
# 2                                         0.33
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
# 2                                         0.20
#
#    ratio_average_daily_clients_last_3/6_months  \
# 0                                         1.50
# 1                                         1.00
# 2                                         1.67
#
#    std_average_daily_clients_last_1/6_months  \
# 0                                       0.50
# 1                                       0.00
# 2                                       1.00
#
#    std_average_daily_clients_last_1/3_months  \
# 0                                       1.00
# 1                                       0.00
# 2                                       2.00
#
#    std_average_daily_clients_last_3/6_months  trading_consistency_score  \
# 0                                       0.50                        -25
# 1                                       0.00                        -50
# 2                                       1.00                        -50
#
#    age_on_network_score  days_since_last_transaction_score  \
# 0                200.00                                200
# 1                200.00                                200
# 2                200.00                                200
#
#    ratio_average_daily_transacted_amount_score  ratio_average_trxn_size_score  \
# 0                                          -50                            -50
# 1                                          -50                            -50
# 2                                          -50                            -50
#
#    total_score  all_loans  repayments loan_band repayments_band  \
# 0       275.00          0           1    Band 1          Band 6
# 1       250.00          0           1    Band 1          Band 6
# 2       250.00          0           1    Band 1          Band 6
#
#    twenty_one_day_limit_factor  seven_day_limit_factor  one_day_limit_factor
# 0                         0.24                    0.12                  0.06
# 1                         0.24                    0.12                  0.06
# 2                         0.24                    0.12                  0.06

# %%
df_encoded_data1['minimum_21_day_limit_on_6_months'] = (df_encoded_data1['average_daily_transacted_amount_last_6_months'] * 30) * df_encoded_data1['twenty_one_day_limit_factor'] 

df_encoded_data1['minimum_7_day_limit_on_6_months'] = (df_encoded_data1['average_daily_transacted_amount_last_6_months'] * 30) * df_encoded_data1['seven_day_limit_factor'] 

df_encoded_data1['minimum_1_day_limit_on_6_months'] = (df_encoded_data1['average_daily_transacted_amount_last_6_months'] * 30) * df_encoded_data1['one_day_limit_factor'] 

df_encoded_data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3867995500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['minimum_21_day_limit_on_6_months'] = (df_encoded_data1['average_daily_transacted_amount_last_6_months'] * 30) * df_encoded_data1['twenty_one_day_limit_factor']
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3867995500.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['minimum_7_day_limit_on_6_months'] = (df_encoded_data1['average_daily_transacted_amount_last_6_months'] * 30) * df_encoded_data1['seven_day_limit_factor']
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3867995500.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['minimum_1_day_limit_on_6_months'] = (df_encoded_data1['average_daily_transacted_amount_last_6_months'] * 30) * df_encoded_data1['one_day_limit_factor']
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN              -4.00         -4             -4.00
# 1        NRIN              -4.00         -4             -4.00
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0            -4.00   2023-01-21 00:00:00  MTNU MoMoPay Informal
# 1            -4.00   2017-10-17 00:00:00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                              -4
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                   -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                        -4.00                     -4.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                   -4.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                          -4.00
# 1                                          -4.00
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                   -4.00
# 1                                   -4.00
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
#
#    ratio_average_daily_clients_last_3/6_months  \
# 0                                         1.50
# 1                                         1.00
#
#    std_average_daily_clients_last_1/6_months  \
# 0                                       0.50
# 1                                       0.00
#
#    std_average_daily_clients_last_1/3_months  \
# 0                                       1.00
# 1                                       0.00
#
#    std_average_daily_clients_last_3/6_months  trading_consistency_score  \
# 0                                       0.50                        -25
# 1                                       0.00                        -50
#
#    age_on_network_score  days_since_last_transaction_score  \
# 0                200.00                                200
# 1                200.00                                200
#
#    ratio_average_daily_transacted_amount_score  ratio_average_trxn_size_score  \
# 0                                          -50                            -50
# 1                                          -50                            -50
#
#    total_score  all_loans  repayments loan_band repayments_band  \
# 0       275.00          0           1    Band 1          Band 6
# 1       250.00          0           1    Band 1          Band 6
#
#    twenty_one_day_limit_factor  seven_day_limit_factor  one_day_limit_factor  \
# 0                         0.24                    0.12                  0.06
# 1                         0.24                    0.12                  0.06
#
#    minimum_21_day_limit_on_6_months  minimum_7_day_limit_on_6_months  \
# 0                         225676.36                        109614.23
# 1                            653.33                           317.33
#
#    minimum_1_day_limit_on_6_months
# 0                         54346.55
# 1                           157.33

# %%
import math as math

def round_off(n):
    """
    This function rounds off elements by setting a ceiling to the next 100
    """
    return int(math.ceil(n / 100.0)) * 100

# %%
def amounts_cap_1_day_product(n):
    if n < 50000:
        return 0
    elif n > 4000000:
        return 4000000
    else:
        return n

# %%
def amounts_cap_7_day_product_with_200_min(n):
    if n < 200000:
        return 0
    elif n > 6000000:
        return 6000000
    else:
        return n

# %%
def amounts_cap_21_day_product(n):
    if n < 500000:
        return 0
    elif n > 10000000:
        return 10000000
    else:
        return n

# %%
## round off limits

df_encoded_data1['rounded_21_day_limit_on_6_months'] = df_encoded_data1['minimum_21_day_limit_on_6_months'].apply(round_off)

df_encoded_data1['rounded_7_day_limit_on_6_months'] = df_encoded_data1['minimum_7_day_limit_on_6_months'].apply(round_off)

df_encoded_data1['rounded_1_day_limit_on_6_months'] = df_encoded_data1['minimum_1_day_limit_on_6_months'].apply(round_off)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2241743387.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['rounded_21_day_limit_on_6_months'] = df_encoded_data1['minimum_21_day_limit_on_6_months'].apply(round_off)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2241743387.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['rounded_7_day_limit_on_6_months'] = df_encoded_data1['minimum_7_day_limit_on_6_months'].apply(round_off)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2241743387.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['rounded_1_day_limit_on_6_months'] = df_encoded_data1['minimum_1_day_limit_on_6_months'].apply(round_off)

# %%
## apply limit caps

df_encoded_data1['final_21_day_limit_on_6_months'] = df_encoded_data1['rounded_21_day_limit_on_6_months'].apply(amounts_cap_21_day_product)

df_encoded_data1['final_7_day_limit_on_6_months_200_min'] = df_encoded_data1['rounded_7_day_limit_on_6_months'].apply(amounts_cap_7_day_product_with_200_min)

df_encoded_data1['final_1_day_limit_on_6_months'] = df_encoded_data1['rounded_1_day_limit_on_6_months'].apply(amounts_cap_1_day_product)

df_encoded_data1.head(3)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1056729392.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['final_21_day_limit_on_6_months'] = df_encoded_data1['rounded_21_day_limit_on_6_months'].apply(amounts_cap_21_day_product)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1056729392.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['final_7_day_limit_on_6_months_200_min'] = df_encoded_data1['rounded_7_day_limit_on_6_months'].apply(amounts_cap_7_day_product_with_200_min)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1056729392.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['final_1_day_limit_on_6_months'] = df_encoded_data1['rounded_1_day_limit_on_6_months'].apply(amounts_cap_1_day_product)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
# 2    169050@momopay  720E74A187312803EB76E049F9275199          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN              -4.00         -4             -4.00
# 1        NRIN              -4.00         -4             -4.00
# 2        NRIN              -4.00         -4             -4.00
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0            -4.00   2023-01-21 00:00:00  MTNU MoMoPay Informal
# 1            -4.00   2017-10-17 00:00:00  MTNU MoMoPay Informal
# 2            -4.00   2023-03-22 00:00:00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
# 2     2023-03-23 11:56:00                   2023-09-18 15:47:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                              -4
# 2                             2023-09-20 08:11:00
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
# 2                     2023-09-12 19:09:00                         8.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
# 2                   435.00                    21.00                    11.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
# 2                     0.00                 21762900               1600400.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
# 2               1,017,900                 -4.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
# 2                         371.00                          15.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
# 2                          10.00                        0.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
# 2                    500000.00                    463000.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
# 2                    463000.00                     -4.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
# 2        2023-09-18 15:47:00            720000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                        -4.00                        -4.00
# 2                        23.00                         8.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                        -4.00                     -4.00
# 2                         1.00                      1.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
# 2                       2.00                       2.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
# 2                       2.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                        -4.00                        -4.00
# 2                  10292208.00                    601000.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                        -4.00                     -4.00
# 2                     50000.00                  50000.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
# 2                  720000.00                  720000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                   -4.00
# 2                  720000.00                   -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                        -4.00                        -4.00
# 2                         8.00                         5.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                        -4.00                     -4.00
# 2                         2.00                      0.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                        -4.00                        -4.00
# 2                    428800.00                    315000.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                        -4.00                     -4.00
# 2                     30000.00                     -4.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
# 2                   127.00                    74.00                    23.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
# 2                   7.00                         6.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
# 2                        182                                       1.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                   -4.00
# 2                    1.00                                   -0.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
# 2                            7.00                 0.29
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
# 2                                      120905.00
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
# 2                                       17782.22
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                          -4.00
# 1                                          -4.00
# 2                                          -4.00
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                              -4.00
# 1                                              -4.00
# 2                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                              -4.00
# 1                                              -4.00
# 2                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
# 2                                               0.15
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
# 2                                           51561.39
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
# 2                                50029.66
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
# 2                                76209.52
#
#    average_transaction_size_last_1_months  \
# 0                                   -4.00
# 1                                   -4.00
# 2                                   -4.00
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                    -4.00
# 1                                    -4.00
# 2                                    -4.00
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                    -4.00
# 1                                    -4.00
# 2                                    -4.00
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
# 2                                     1.52
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
# 2                               13089.93                               435.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
# 2                                21.00                                11.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
# 2                                      3.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
# 2                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
# 2                                              0.33
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
# 2                                            1.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
# 2                          371.00                           15.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
# 2                           10.00                                 3.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
# 2                                 5.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
# 2                                         0.33
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
# 2                                         0.20
#
#    ratio_average_daily_clients_last_3/6_months  \
# 0                                         1.50
# 1                                         1.00
# 2                                         1.67
#
#    std_average_daily_clients_last_1/6_months  \
# 0                                       0.50
# 1                                       0.00
# 2                                       1.00
#
#    std_average_daily_clients_last_1/3_months  \
# 0                                       1.00
# 1                                       0.00
# 2                                       2.00
#
#    std_average_daily_clients_last_3/6_months  trading_consistency_score  \
# 0                                       0.50                        -25
# 1                                       0.00                        -50
# 2                                       1.00                        -50
#
#    age_on_network_score  days_since_last_transaction_score  \
# 0                200.00                                200
# 1                200.00                                200
# 2                200.00                                200
#
#    ratio_average_daily_transacted_amount_score  ratio_average_trxn_size_score  \
# 0                                          -50                            -50
# 1                                          -50                            -50
# 2                                          -50                            -50
#
#    total_score  all_loans  repayments loan_band repayments_band  \
# 0       275.00          0           1    Band 1          Band 6
# 1       250.00          0           1    Band 1          Band 6
# 2       250.00          0           1    Band 1          Band 6
#
#    twenty_one_day_limit_factor  seven_day_limit_factor  one_day_limit_factor  \
# 0                         0.24                    0.12                  0.06
# 1                         0.24                    0.12                  0.06
# 2                         0.24                    0.12                  0.06
#
#    minimum_21_day_limit_on_6_months  minimum_7_day_limit_on_6_months  \
# 0                         225676.36                        109614.23
# 1                            653.33                           317.33
# 2                         888651.75                        431630.85
#
#    minimum_1_day_limit_on_6_months  rounded_21_day_limit_on_6_months  \
# 0                         54346.55                            225700
# 1                           157.33                               700
# 2                        214001.85                            888700
#
#    rounded_7_day_limit_on_6_months  rounded_1_day_limit_on_6_months  \
# 0                           109700                            54400
# 1                              400                              200
# 2                           431700                           214100
#
#    final_21_day_limit_on_6_months  final_7_day_limit_on_6_months_200_min  \
# 0                               0                                      0
# 1                               0                                      0
# 2                          888700                                 431700
#
#    final_1_day_limit_on_6_months
# 0                          54400
# 1                              0
# 2                         214100

# %%
### pilot limits that are 50% of allocated limit

df_encoded_data1['pilot_final_21_day_limit_on_6_months'] = round(df_encoded_data1['final_21_day_limit_on_6_months'] * 0.5)

df_encoded_data1['pilot_final_7_day_limit_on_6_months'] = round(df_encoded_data1['final_7_day_limit_on_6_months_200_min'] * 0.5)

df_encoded_data1['pilot_final_1_day_limit_on_6_months'] = round(df_encoded_data1['final_1_day_limit_on_6_months'] * 0.5)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1348713390.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['pilot_final_21_day_limit_on_6_months'] = round(df_encoded_data1['final_21_day_limit_on_6_months'] * 0.5)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1348713390.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['pilot_final_7_day_limit_on_6_months'] = round(df_encoded_data1['final_7_day_limit_on_6_months_200_min'] * 0.5)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1348713390.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['pilot_final_1_day_limit_on_6_months'] = round(df_encoded_data1['final_1_day_limit_on_6_months'] * 0.5)

# %%
def check_21_day_product_min_after_50_pc_slash(df):
    
    pilot_twenty_one_day_limit = df['pilot_final_21_day_limit_on_6_months']
    
    if pilot_twenty_one_day_limit < 500000:
        return 500000
    else :
        return pilot_twenty_one_day_limit

# %%
def check_7_day_product_min_after_50_pc_slash(df):
    
    pilot_seven_one_day_limit = df['pilot_final_7_day_limit_on_6_months']
    
    if pilot_seven_one_day_limit < 200000:
        return 200000
    else :
        return pilot_seven_one_day_limit

# %%
def check_1_day_product_min_after_50_pc_slash(df):
    
    pilot_one_day_limit = df['pilot_final_1_day_limit_on_6_months']
    
    if pilot_one_day_limit < 50000:
        return 50000
    elif pilot_one_day_limit > 500000:
        return 500000
    else :
        return pilot_one_day_limit

# %%
df_encoded_data1['pilot_final_21_day_limit_on_6_months'] = df_encoded_data1.apply(lambda x : check_21_day_product_min_after_50_pc_slash(x), axis = 1)

df_encoded_data1['pilot_final_7_day_limit_on_6_months'] = df_encoded_data1.apply(lambda x : check_7_day_product_min_after_50_pc_slash(x), axis = 1)

df_encoded_data1['pilot_final_1_day_limit_on_6_months'] = df_encoded_data1.apply(lambda x : check_1_day_product_min_after_50_pc_slash(x), axis = 1)

df_encoded_data1.head(2)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1920205295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['pilot_final_21_day_limit_on_6_months'] = df_encoded_data1.apply(lambda x : check_21_day_product_min_after_50_pc_slash(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1920205295.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['pilot_final_7_day_limit_on_6_months'] = df_encoded_data1.apply(lambda x : check_7_day_product_min_after_50_pc_slash(x), axis = 1)
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\1920205295.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_encoded_data1['pilot_final_1_day_limit_on_6_months'] = df_encoded_data1.apply(lambda x : check_1_day_product_min_after_50_pc_slash(x), axis = 1)
#   kyc_merchant_code                      id_number_ah kyc_merchant_type  \
# 0    161902@momopay  BCB66B2419392C28249EEE548F7FEEC8          PERSONAL
# 1    407855@momopay  226A13B02D01E43C1A09398E54C4880D          PERSONAL
#
#   kyc_id_type  kyc_business_type kyc_id_num  kyc_first_name_2  \
# 0        NRIN              -4.00         -4             -4.00
# 1        NRIN              -4.00         -4             -4.00
#
#    kyc_last_name_2 mom_registration_date                profile  \
# 0            -4.00   2023-01-21 00:00:00  MTNU MoMoPay Informal
# 1            -4.00   2017-10-17 00:00:00  MTNU MoMoPay Informal
#
#   MoMoPay_fst_actvty_date date_last_receipt_into_momopay_wallet  \
# 0     2023-02-20 10:25:00                   2023-09-20 18:33:00
# 1     2019-11-11 15:24:00                   2023-09-20 14:17:00
#
#   date_last_transfer_from_momopay_to_mobile_money  \
# 0                             2023-09-20 22:07:00
# 1                                              -4
#
#   date_last_transfer_from_momopay_to_bank  MOM_momo_TransactionsPerDay  \
# 0                     2023-09-20 18:56:00                         4.00
# 1                     2023-09-15 17:26:00                         1.00
#
#    MOM_momo_PAYMENT_QTY_6M  MOM_momo_PAYMENT_QTY_3M  MOM_momo_PAYMENT_QTY_1M  \
# 0                   272.00                    65.00                     6.00
# 1                    32.00                    25.00                     4.00
#
#    MOM_momo_PAYMENT_QTY_1D  MOM_momo_PAYMENT_AMT_6M  MOM_momo_PAYMENT_AMT_3M  \
# 0                     1.00                  5526768               2905418.00
# 1                     1.00                    16000                 12500.00
#
#   MOM_momo_PAYMENT_AMT_1M  DAY_momo_PAYMENT_AMT  \
# 0                 183,346              97000.00
# 1                   2,000                500.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_6M  MOM_momo_PAYMENT_ACCEPTORS_3M  \
# 0                         191.00                          48.00
# 1                          32.00                          25.00
#
#    MOM_momo_PAYMENT_ACCEPTORS_1M  DAY_momo_PAYMENT_ACCEPTORS  \
# 0                           5.00                        1.00
# 1                           4.00                        1.00
#
#    MOM_momo_PAYMENT_MAX_AMT_6M  MOM_momo_PAYMENT_MAX_AMT_3M  \
# 0                    249000.00                    208007.00
# 1                       500.00                       500.00
#
#    MOM_momo_PAYMENT_MAX_AMT_1M  DAY_momo_PAYMENT_MAX_AMT  \
# 0                     97000.00                  97000.00
# 1                       500.00                    500.00
#
#   MOM_momo_PAYMENT_LAST_DATE  MOM_momo_Withdrawal  \
# 0        2023-09-20 18:33:00             96000.00
# 1        2023-09-20 14:17:00             15000.00
#
#    MOM_momo_Till_Wallet_QTY_6M  MOM_momo_Till_Wallet_QTY_3M  \
# 0                       108.00                        14.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_Till_Wallet_QTY_1M  DAY_momo_Till_Wallet_QTY  \
# 0                         6.00                      1.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_Till_Bank_QTY_6M  MOM_momo_Till_Bank_QTY_3M  \
# 0                       1.00                       1.00
# 1                       1.00                       1.00
#
#    MOM_momo_Till_Bank_QTY_1M  DAY_momo_Till_Bank_QTY  \
# 0                       1.00                    1.00
# 1                       1.00                    0.00
#
#    MOM_momo_Till_Wallet_AMT_6M  MOM_momo_Till_Wallet_AMT_3M  \
# 0                   2688470.00                    360201.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_Till_Wallet_AMT_1M  DAY_momo_Till_Wallet_AMT  \
# 0                     17912.00                    700.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_Till_Bank_AMT_6M  MOM_momo_Till_Bank_AMT_3M  \
# 0                   96000.00                   96000.00
# 1                   15000.00                   15000.00
#
#    MOM_momo_Till_Bank_AMT_1M  DAY_momo_Till_Bank_AMT  \
# 0                   96000.00                96000.00
# 1                   15000.00                   -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_6M  MOM_momo_m2m_PAYMENT_QTY_3M  \
# 0                       244.00                        60.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_QTY_1M  DAY_momo_m2m_PAYMENT_QTY  \
# 0                         4.00                      1.00
# 1                        -4.00                     -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_6M  MOM_momo_m2m_PAYMENT_AMT_3M  \
# 0                   5228893.00                   2866418.00
# 1                        -4.00                        -4.00
#
#    MOM_momo_m2m_PAYMENT_AMT_1M  DAY_momo_m2m_PAYMENT_AMT  \
# 0                    175346.00                  97000.00
# 1                        -4.00                     -4.00
#
#    MOMO_No_Activity_QTY_6M  MOMO_No_Activity_QTY_3M  MOMO_No_Activity_QTY_1M  \
# 0                   111.00                    71.00                    26.00
# 1                   152.00                    68.00                    26.00
#
#    age_on_network_months  months_since_first_activity  \
# 0                   9.00                         7.00
# 1                  72.00                        46.00
#
#    days_since_first_activity  days_btwn_joining_and_first_activity_date  \
# 0                        213                                      30.00
# 1                       1409                                     756.00
#
#    days_since_last_pay_in  days_since_last_payout_to_mobile_money  \
# 0                   -1.00                                   -1.00
# 1                   -1.00                                   -4.00
#
#    days_since_last_payout_to_bank  trading_consistency  \
# 0                           -1.00                 0.38
# 1                            4.00                 0.16
#
#    average_daily_transacted_amount_last_6_months  \
# 0                                       30704.27
# 1                                          88.89
#
#    average_daily_transacted_amount_last_3_months  \
# 0                                       32282.42
# 1                                         138.89
#
#    average_daily_transacted_amount_last_1_months  \
# 0                                          -4.00
# 1                                          -4.00
#
#    ratio_average_daily_transacted_amount_last_1/6_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_1/3_months  \
# 0                                              -4.00
# 1                                              -4.00
#
#    ratio_average_daily_transacted_amount_last_3/6_months  \
# 0                                               1.05
# 1                                               1.56
#
#    std_average_daily_transacted_amount_last_1/6_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_1/3_months  \
# 0                                               0.00
# 1                                               0.00
#
#    std_average_daily_transacted_amount_last_3/6_months  \
# 0                                             789.08
# 1                                              25.00
#
#    average_transaction_size_last_6_months  \
# 0                                20319.00
# 1                                  500.00
#
#    average_transaction_size_last_3_months  \
# 0                                44698.74
# 1                                  500.00
#
#    average_transaction_size_last_1_months  \
# 0                                   -4.00
# 1                                   -4.00
#
#    ratio_average_trxn_size_last_1/6_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_1/3_months  \
# 0                                    -4.00
# 1                                    -4.00
#
#    ratio_average_trxn_size_last_3/6_months  \
# 0                                     2.20
# 1                                     1.00
#
#    std_average_trxn_size_last_1/6_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_1/3_months  \
# 0                                   0.00
# 1                                   0.00
#
#    std_average_trxn_size_last_3/6_months  count_of_transactions_last_6_months  \
# 0                               12189.87                               272.00
# 1                                   0.00                                32.00
#
#    count_of_transactions_last_3_months  count_of_transactions_last_1_months  \
# 0                                65.00                                 6.00
# 1                                25.00                                 4.00
#
#    average_daily_transactions_last_6_months  \
# 0                                      2.00
# 1                                      1.00
#
#    average_daily_transactions_last_3_months  \
# 0                                      1.00
# 1                                      1.00
#
#    average_daily_transactions_last_1_months  \
# 0                                      1.00
# 1                                      1.00
#
#    ratio_average_daily_transactions_last_1/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_1/3_months  \
# 0                                              1.00
# 1                                              1.00
#
#    ratio_average_daily_transactions_last_3/6_months  \
# 0                                              0.50
# 1                                              1.00
#
#    std_average_daily_transactions_last_1/6_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_1/3_months  \
# 0                                            0.00
# 1                                            0.00
#
#    std_average_daily_transactions_last_3/6_months  \
# 0                                            0.50
# 1                                            0.00
#
#    count_of_clients_last_6_months  count_of_clients_last_3_months  \
# 0                          191.00                           48.00
# 1                           32.00                           25.00
#
#    count_of_clients_last_1_months  average_daily_clients_last_6_months  \
# 0                            5.00                                 2.00
# 1                            4.00                                 1.00
#
#    average_daily_clients_last_3_months  average_daily_clients_last_1_months  \
# 0                                 3.00                                 1.00
# 1                                 1.00                                 1.00
#
#    ratio_average_daily_clients_last_1/6_months  \
# 0                                         0.50
# 1                                         1.00
#
#    ratio_average_daily_clients_last_1/3_months  \
# 0                                         0.33
# 1                                         1.00
#
#    ratio_average_daily_clients_last_3/6_months  \
# 0                                         1.50
# 1                                         1.00
#
#    std_average_daily_clients_last_1/6_months  \
# 0                                       0.50
# 1                                       0.00
#
#    std_average_daily_clients_last_1/3_months  \
# 0                                       1.00
# 1                                       0.00
#
#    std_average_daily_clients_last_3/6_months  trading_consistency_score  \
# 0                                       0.50                        -25
# 1                                       0.00                        -50
#
#    age_on_network_score  days_since_last_transaction_score  \
# 0                200.00                                200
# 1                200.00                                200
#
#    ratio_average_daily_transacted_amount_score  ratio_average_trxn_size_score  \
# 0                                          -50                            -50
# 1                                          -50                            -50
#
#    total_score  all_loans  repayments loan_band repayments_band  \
# 0       275.00          0           1    Band 1          Band 6
# 1       250.00          0           1    Band 1          Band 6
#
#    twenty_one_day_limit_factor  seven_day_limit_factor  one_day_limit_factor  \
# 0                         0.24                    0.12                  0.06
# 1                         0.24                    0.12                  0.06
#
#    minimum_21_day_limit_on_6_months  minimum_7_day_limit_on_6_months  \
# 0                         225676.36                        109614.23
# 1                            653.33                           317.33
#
#    minimum_1_day_limit_on_6_months  rounded_21_day_limit_on_6_months  \
# 0                         54346.55                            225700
# 1                           157.33                               700
#
#    rounded_7_day_limit_on_6_months  rounded_1_day_limit_on_6_months  \
# 0                           109700                            54400
# 1                              400                              200
#
#    final_21_day_limit_on_6_months  final_7_day_limit_on_6_months_200_min  \
# 0                               0                                      0
# 1                               0                                      0
#
#    final_1_day_limit_on_6_months  pilot_final_21_day_limit_on_6_months  \
# 0                          54400                             500000.00
# 1                              0                             500000.00
#
#    pilot_final_7_day_limit_on_6_months  pilot_final_1_day_limit_on_6_months
# 0                            200000.00                             50000.00
# 1                            200000.00                             50000.00

# %%
## New

qualified_on_800 = df_encoded_data1[(df_encoded_data1['total_score'] >= 800 ) & 
                                   (df_encoded_data1['final_21_day_limit_on_6_months'] > 0) & 
                                   (df_encoded_data1['pilot_final_21_day_limit_on_6_months'])]

print(qualified_on_800.shape)

print(qualified_on_800['final_21_day_limit_on_6_months'].sum())

print(qualified_on_800['pilot_final_21_day_limit_on_6_months'].sum())
# Out:
# (0, 135)
# 0
# 0.0

# %%
## New

qualified_on_800 = df_encoded_data1[(df_encoded_data1['total_score'] >= 800) & 
                                   (df_encoded_data1['final_21_day_limit_on_6_months'] > 0) & 
                                   (df_encoded_data1['pilot_final_21_day_limit_on_6_months'])]
# qualified_on_800 = df_encoded_data1[(df_encoded_data1['total_score'] >= 600 )]
#                                    (df_encoded_data1['final_21_day_limit_on_6_months'] > 0)] 
#                                    (df_encoded_data1['pilot_final_21_day_limit_on_6_months'])]

print(qualified_on_800.shape)

print(qualified_on_800['final_21_day_limit_on_6_months'].sum())

print(qualified_on_800['pilot_final_21_day_limit_on_6_months'].sum())
# Out:
# (0, 135)
# 0
# 0.0

# %%
DataFrame_Final= df_encoded_data1.copy()

# %%
def rule_qualification(DataFrame_Final,score_threshhold,total_score_threshhold):
    
    Qualified_on_ratio_average_trxn_size_score=DataFrame_Final[DataFrame_Final["ratio_average_trxn_size_score"]>=score_threshhold]["kyc_merchant_code"].shape[0]

    Qualified_on_ratio_average_daily_transacted_amount_score=DataFrame_Final[DataFrame_Final["ratio_average_daily_transacted_amount_score"]>=score_threshhold]["kyc_merchant_code"].shape[0]

    Qualified_on_age_on_network_score=DataFrame_Final[DataFrame_Final["age_on_network_score"]>=score_threshhold]["kyc_merchant_code"].shape[0]

    Qualified_on_days_since_last_transaction_score=DataFrame_Final[DataFrame_Final["days_since_last_transaction_score"]>=score_threshhold]["kyc_merchant_code"].shape[0]

    
    Qualified_on_trading_consistency_score=DataFrame_Final[DataFrame_Final["trading_consistency_score"]>=score_threshhold]["kyc_merchant_code"].shape[0]
    Qualified_on_trading_total_score=DataFrame_Final[DataFrame_Final["total_score"]>=total_score_threshhold]["kyc_merchant_code"].shape[0]
    
    data = {
    'trading_consistency_score':Qualified_on_trading_consistency_score ,
    'days_since_last_transaction_score': Qualified_on_days_since_last_transaction_score,
    'age_on_network_score':Qualified_on_age_on_network_score,
    'ratio_average_daily_transacted_amount_score':Qualified_on_ratio_average_daily_transacted_amount_score,
    'ratio_average_trxn_size_score':Qualified_on_ratio_average_trxn_size_score,
    'total_score':Qualified_on_trading_total_score
    
} 
    
    df = pd.DataFrame(data, index=[0])
#     df.to_csv("MTN_DATA2_rules_qualification_summary.csv")
    
    return df

rule_score_summary=rule_qualification(DataFrame_Final=DataFrame_Final,score_threshhold=200,total_score_threshhold=800)

rule_score_summary
# Out:
#    trading_consistency_score  days_since_last_transaction_score  \
# 0                       2455                             207979
#
#    age_on_network_score  ratio_average_daily_transacted_amount_score  \
# 0                118688                                         2144
#
#    ratio_average_trxn_size_score  total_score
# 0                            352            0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import ScalarFormatter
score_columns = [col for col in df_encoded_data1.columns if "score" in col.lower()]
num_columns = 2
num_rows = (len(score_columns) + 1) // num_columns
fig, axes = plt.subplots(num_rows, num_columns, figsize=(14, 8))
axes = axes.flatten()
bg_color = 'lightblue'
bar_colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'lightcoral', 'deepskyblue']
for i, (col, color) in enumerate(zip(score_columns, bar_colors)):
    # Display summary statistics
#     print(df_encoded_data1[col].describe().T)
    sns.histplot(df_encoded_data1[col], kde=True, bins=10, color=color, ax=axes[i])
    axes[i].set_facecolor(bg_color)
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count of merchants')
for i in range(len(score_columns), len(axes)):
    fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %%
Individual = df_encoded_data1[df_encoded_data1["kyc_merchant_code"]=="61902@momopay"]
Individual
# Out:
# Empty DataFrame
# Columns: [kyc_merchant_code, id_number_ah, kyc_merchant_type, kyc_id_type, kyc_business_type, kyc_id_num, kyc_first_name_2, kyc_last_name_2, mom_registration_date, profile, MoMoPay_fst_actvty_date, date_last_receipt_into_momopay_wallet, date_last_transfer_from_momopay_to_mobile_money, date_last_transfer_from_momopay_to_bank, MOM_momo_TransactionsPerDay, MOM_momo_PAYMENT_QTY_6M, MOM_momo_PAYMENT_QTY_3M, MOM_momo_PAYMENT_QTY_1M, MOM_momo_PAYMENT_QTY_1D, MOM_momo_PAYMENT_AMT_6M, MOM_momo_PAYMENT_AMT_3M, MOM_momo_PAYMENT_AMT_1M, DAY_momo_PAYMENT_AMT, MOM_momo_PAYMENT_ACCEPTORS_6M, MOM_momo_PAYMENT_ACCEPTORS_3M, MOM_momo_PAYMENT_ACCEPTORS_1M, DAY_momo_PAYMENT_ACCEPTORS, MOM_momo_PAYMENT_MAX_AMT_6M, MOM_momo_PAYMENT_MAX_AMT_3M, MOM_momo_PAYMENT_MAX_AMT_1M, DAY_momo_PAYMENT_MAX_AMT, MOM_momo_PAYMENT_LAST_DATE, MOM_momo_Withdrawal, MOM_momo_Till_Wallet_QTY_6M, MOM_momo_Till_Wallet_QTY_3M, MOM_momo_Till_Wallet_QTY_1M, DAY_momo_Till_Wallet_QTY, MOM_momo_Till_Bank_QTY_6M, MOM_momo_Till_Bank_QTY_3M, MOM_momo_Till_Bank_QTY_1M, DAY_momo_Till_Bank_QTY, MOM_momo_Till_Wallet_AMT_6M, MOM_momo_Till_Wallet_AMT_3M, MOM_momo_Till_Wallet_AMT_1M, DAY_momo_Till_Wallet_AMT, MOM_momo_Till_Bank_AMT_6M, MOM_momo_Till_Bank_AMT_3M, MOM_momo_Till_Bank_AMT_1M, DAY_momo_Till_Bank_AMT, MOM_momo_m2m_PAYMENT_QTY_6M, MOM_momo_m2m_PAYMENT_QTY_3M, MOM_momo_m2m_PAYMENT_QTY_1M, DAY_momo_m2m_PAYMENT_QTY, MOM_momo_m2m_PAYMENT_AMT_6M, MOM_momo_m2m_PAYMENT_AMT_3M, MOM_momo_m2m_PAYMENT_AMT_1M, DAY_momo_m2m_PAYMENT_AMT, MOMO_No_Activity_QTY_6M, MOMO_No_Activity_QTY_3M, MOMO_No_Activity_QTY_1M, age_on_network_months, months_since_first_activity, days_since_first_activity, days_btwn_joining_and_first_activity_date, days_since_last_pay_in, days_since_last_payout_to_mobile_money, days_since_last_payout_to_bank, trading_consistency, average_daily_transacted_amount_last_6_months, average_daily_transacted_amount_last_3_months, average_daily_transacted_amount_last_1_months, ratio_average_daily_transacted_amount_last_1/6_months, ratio_average_daily_transacted_amount_last_1/3_months, ratio_average_daily_transacted_amount_last_3/6_months, std_average_daily_transacted_amount_last_1/6_months, std_average_daily_transacted_amount_last_1/3_months, std_average_daily_transacted_amount_last_3/6_months, average_transaction_size_last_6_months, average_transaction_size_last_3_months, average_transaction_size_last_1_months, ratio_average_trxn_size_last_1/6_months, ratio_average_trxn_size_last_1/3_months, ratio_average_trxn_size_last_3/6_months, std_average_trxn_size_last_1/6_months, std_average_trxn_size_last_1/3_months, std_average_trxn_size_last_3/6_months, count_of_transactions_last_6_months, count_of_transactions_last_3_months, count_of_transactions_last_1_months, average_daily_transactions_last_6_months, average_daily_transactions_last_3_months, average_daily_transactions_last_1_months, ratio_average_daily_transactions_last_1/6_months, ratio_average_daily_transactions_last_1/3_months, ratio_average_daily_transactions_last_3/6_months, std_average_daily_transactions_last_1/6_months, std_average_daily_transactions_last_1/3_months, std_average_daily_transactions_last_3/6_months, count_of_clients_last_6_months, count_of_clients_last_3_months, ...]
# Index: []

# %% [markdown]
# #### Data2 Summary

# %%
def summary(df_encoded_data1):
    Total_Scored =df_encoded_data1.shape[0]
    
    total_qualified_21 = df_encoded_data1[df_encoded_data1['pilot_final_21_day_limit_on_6_months']>500000].shape[0]

#     total_qualified_21 =total_qualified_21.shape[0]
    percent_qualified_21=df_encoded_data1[df_encoded_data1['pilot_final_21_day_limit_on_6_months']>500000]

    percent_qualified_21 =round((percent_qualified_21.shape[0]/df_encoded_data1['pilot_final_21_day_limit_on_6_months'].shape[0]*100),2)
    total_value_21=df_encoded_data1[df_encoded_data1['pilot_final_21_day_limit_on_6_months']>500000]

    total_value_21 =total_value_21['pilot_final_21_day_limit_on_6_months'].sum()
    total_qualified_7 = df_encoded_data1[df_encoded_data1['pilot_final_7_day_limit_on_6_months']>200000].shape[0]

#     total_qualified_7 =total_qualified_7.shape[0]

    percent_qualified_7=df_encoded_data1[df_encoded_data1['pilot_final_7_day_limit_on_6_months']>200000]

    percent_qualified_7 =round((percent_qualified_7.shape[0]/df_encoded_data1['pilot_final_7_day_limit_on_6_months'].shape[0]*100),2)
    
    total_value_7=df_encoded_data1[df_encoded_data1['pilot_final_7_day_limit_on_6_months']>200000]

    total_value_7 =total_value_7['pilot_final_7_day_limit_on_6_months'].sum()
    total_qualified_1 = df_encoded_data1[df_encoded_data1['pilot_final_1_day_limit_on_6_months']>50000].shape[0]

#     total_qualified_1 =total_qualified_1.shape[0]
    percent_qualified_1=df_encoded_data1[df_encoded_data1['pilot_final_1_day_limit_on_6_months']>50000]

    percent_qualified_1 =round((percent_qualified_1.shape[0]/df_encoded_data1['pilot_final_1_day_limit_on_6_months'].shape[0]*100),2)
    total_value_1=df_encoded_data1[df_encoded_data1['pilot_final_1_day_limit_on_6_months']>50000]

    total_value_1 =total_value_1['pilot_final_1_day_limit_on_6_months'].sum()
    
    Summary  = {
    'Product': ['21_day_Product', '7_day_Product', '1_day_Product'],
    'Total_Scored': [Total_Scored,Total_Scored, Total_Scored],
    'Global_limit': [total_value_21, total_value_7, total_value_1],
    'Total_with_Pilot_Limits': [total_qualified_21, total_qualified_7, total_qualified_1],
    '%_with_Pilot_limits': [percent_qualified_21, percent_qualified_7, percent_qualified_1]
}

    data2_Summary_data = pd.DataFrame(Summary)
    
    return data2_Summary_data


data2_Summary_data=summary(df_encoded_data1)
data2_Summary_data
# Out:
#           Product  Total_Scored  Global_limit  Total_with_Pilot_Limits  \
# 0  21_day_Product        342872 3705111350.00                     2158
# 1   7_day_Product        342872 1971407700.00                     2500
# 2   1_day_Product        342872  814577250.00                     4098
#
#    %_with_Pilot_limits
# 0                 0.63
# 1                 0.73
# 2                 1.20

# %% [markdown]
# #### Data2 Send to Digital

# %%
To_Digital = df_encoded_data1[['kyc_merchant_code','pilot_final_1_day_limit_on_6_months','pilot_final_7_day_limit_on_6_months','pilot_final_21_day_limit_on_6_months']]

To_Digital.rename(columns={
    'kyc_merchant_code': 'customer_code',
    'pilot_final_1_day_limit_on_6_months': 'limit_1day',
    'pilot_final_7_day_limit_on_6_months': 'limit_7day',
    'pilot_final_21_day_limit_on_6_months': 'limit_21day'
}, inplace=True)
To_Digital.columns
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\2543414413.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   To_Digital.rename(columns={
# Index(['customer_code', 'limit_1day', 'limit_7day', 'limit_21day'], dtype='object')

# %%
import pymysql
from sqlalchemy import create_engine
from urllib.parse import quote_plus


To_Digital = df_encoded_data1[['kyc_merchant_code','pilot_final_1_day_limit_on_6_months','pilot_final_7_day_limit_on_6_months','pilot_final_21_day_limit_on_6_months']]

To_Digital.rename(columns={
    'kyc_merchant_code': 'customer_code',
    'pilot_final_1_day_limit_on_6_months': 'limit_1day',
    'pilot_final_7_day_limit_on_6_months': 'limit_7day',
    'pilot_final_21_day_limit_on_6_months': 'limit_21day'
}, inplace=True)
To_Digital.columns

def send_dataframe_to_mysql(dataframe, table_name, host, username, password, database):
    try:
        db_connection = pymysql.connect(
            host=host,
            user=username,
            password=password,
            database=database
        )

        engine = create_engine(f'mysql+pymysql://{username}:{quote_plus(password)}@{host}/{database}')
       


        dataframe.to_sql(name=table_name, con=engine, if_exists='append', index=False)

        print("Data sent to MySQL successfully.")

    except Exception as e:
        print(f"Error: {str(e)}")

    finally:
        db_connection.close()
    
        
        
dataframe =To_Digital
table_name = 'mtn_scoring_result'
host = '3.69.153.77'
username = "appuser"
password = "S@1Oe8Szxn76"
database = "mtn"

# send_dataframe_to_mysql(dataframe, table_name, host, username, password, database)
# Out:
# C:\Users\Stephen.Oguna\AppData\Local\Temp\ipykernel_6408\3231749633.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   To_Digital.rename(columns={

# %%
To_Digital.to_csv("2O-09-2023_MTN_Dataset_Scoring_results.csv")

# %%
To_Digital.shape
# Out:
# (342872, 4)
